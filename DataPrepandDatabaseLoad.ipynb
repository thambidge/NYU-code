# %% [markdown]
# # Data Preparation and Database Load

# %% [markdown]
# This notebook reads in all the individual files that were downloaded from federal reporter (https://federalreporter.nih.gov/FileDownload) and creates three final datasets: Project, Abstract, Publications. The datasets contain info on project, abstract and publication by year. The data structure is organized in a longitundinal format having one observation per year.

# %%
# general use imports
import datetime
import glob
import inspect
import numpy
import os
import six
import warnings
warnings.filterwarnings('ignore')

# pandas-related imports
import pandas as pd
import sqlalchemy

# CSV file reading-related imports
import csv

# database interaction imports
import psycopg2

# %%
# Store the notebook's home directory in a variable
notebook_home_directory = os.getcwd()
print( "Home directory = " + notebook_home_directory )
# Out:
# Home directory = /wingrdp/homedirs/deh341/ada_pub

# %%
# Store the path to the data directory
data_directory_prj = "~/FederalReporter/projects"
data_directory_abs = "~/FederalReporter/abstracts"
data_directory_pub = "~/FederalReporter/publications"
data_directory_key = "~/FederalReporter/key"
data_directory_out = "~/FederalReporter/out"

print( "Data directory for Project Info = " + data_directory_prj )
print( "Data directory for Abstract Info = " + data_directory_abs )
print( "Data directory for Publication Info = " + data_directory_pub )
print( "Data directory for Crosswalk Info = " + data_directory_key )
print( "Data directory for Output files = " + data_directory_out )
# Out:
# Data directory for Project Info = ~/FederalReporter/projects
# Data directory for Abstract Info = ~/FederalReporter/abstracts
# Data directory for Publication Info = ~/FederalReporter/publications
# Data directory for Crosswalk Info = ~/FederalReporter/key
# Data directory for Output files = ~/FederalReporter/out

# %% [markdown]
# # Project Files

# %%
# %cd $data_directory_prj
# Out:
# /gpfs1/cusp/deh341/FederalReporter/projects

# %%
# Append all the yearly files into one file
df_prj = pd.DataFrame() #initializes DF which will hold aggregated csv files

for f in glob.glob("*.csv"): #for all csv files in pwd
    df = pd.read_csv(f, low_memory=False) #create dataframe for reading current csv
    df_prj = df_prj.append(df, ignore_index=True) #appends current csv to final DF

# %%
# See what is available (notice we have some whitespaces here)
df_prj.count()
# Out:
# PROJECT_ID                     894014
#  PROJECT_TERMS                 894013
#  PROJECT_TITLE                 894014
#  DEPARTMENT                    894014
#  AGENCY                        894014
#  IC_CENTER                     724197
#  PROJECT_NUMBER                894014
#  PROJECT_START_DATE            778532
#  PROJECT_END_DATE              793081
#  CONTACT_PI_PROJECT_LEADER     893919
#  OTHER_PIS                      98771
#  CONGRESSIONAL_DISTRICT        830210
#  DUNS_NUMBER                   883561
#  ORGANIZATION_NAME             893492
#  ORGANIZATION_CITY             889995
#  ORGANIZATION_STATE            880642
#  ORGANIZATION_ZIP              852989
#  ORGANIZATION_COUNTRY          890167
#  BUDGET_START_DATE             679756
#  BUDGET_END_DATE               679737
#  CFDA_CODE                     744484
#  FY                            894014
#  FY_TOTAL_COST                 727360
#  FY_TOTAL_COST_SUB_PROJECTS    134513
# dtype: int64

# %%
# Remove Whitespaces
df_prj.rename(columns=lambda x: x.strip(), inplace=True)

# %%
# Make columns lower case
df_prj.columns = map(str.lower, df_prj.columns)

# %%
# Look at the first 5 entries
df_prj.head()
# Out:
#    project_id                                      project_terms  \
# 0      584395   Address; Aflatoxins; Arachis hypogaea; Area; ...
# 1      584396   base; Benign; Chemicals; cold temperature; De...
# 2      584397   Acer; Alder plant; Biochemical; Breeding; Cli...
# 3      584398   Adjuvant; Agriculture; Bacillus thuringiensis...
# 4      584399   Anthocyanins; Area; Berry; Characteristics; C...
#
#                                        project_title department agency  \
# 0  DEVELOP AND TRANSFER IRRIGATED AND NON-IRRIGAT...       USDA    ARS
# 1                     SMALL FRUIT PRODUCTION SYSTEMS       USDA    ARS
# 2  GENETIC IMPROVEMENT OF LANDSCAPE TREES FOR SUP...       USDA    ARS
# 3  IMPROVING CROP PROTECTION TECHNOLOGY FOR HORTI...       USDA    ARS
# 4  PRODUCTION SYSTEMS TO PROMOTE YIELD AND QUALIT...       USDA    ARS
#
#   ic_center project_number project_start_date project_end_date  \
# 0       NaN    ARS-0407399         10/22/2003       10/21/2008
# 1       NaN    ARS-0407571         11/28/2003       11/27/2008
# 2       NaN    ARS-0407833         11/19/2003       10/31/2008
# 3       NaN    ARS-0407835         10/29/2003       10/28/2008
# 4       NaN    ARS-0407838         11/16/2003       11/15/2008
#
#   contact_pi_project_leader            ...             organization_city  \
# 0        SORENSEN, RONALD B            ...                        DAWSON
# 1           TAKEDA, FUMIOMI            ...                 KEARNEYSVILLE
# 2          OLSEN, RICHARD T            ...                    WASHINGTON
# 3        DERKSEN, RICHARD C            ...                       WOOSTER
# 4           TARARA, JULIE M            ...                     CORVALLIS
#
#    organization_state organization_zip organization_country budget_start_date  \
# 0                  GA            39842        UNITED STATES               NaN
# 1                  WV            25430        UNITED STATES               NaN
# 2                  DC            20002        UNITED STATES               NaN
# 3                  OH            44691        UNITED STATES               NaN
# 4                  OR            97331        UNITED STATES               NaN
#
#   budget_end_date cfda_code    fy fy_total_cost fy_total_cost_sub_projects
# 0             NaN    10.001  2004           NaN                        NaN
# 1             NaN    10.001  2004           NaN                        NaN
# 2             NaN    10.001  2004           NaN                        NaN
# 3             NaN    10.001  2004           NaN                        NaN
# 4             NaN    10.001  2004           NaN                        NaN
#
# [5 rows x 24 columns]

# %%
# Save dataframe as csv for data ingestion
# %cd $data_directory_out
df_prj.to_csv('FedExPrj0416.csv')
# Out:
# /gpfs1/cusp/deh341/FederalReporter/out

# %% [markdown]
# # Abstract Files

# %%
# %cd $data_directory_abs
# Out:
# /gpfs1/cusp/deh341/FederalReporter/abstracts

# %%
# Append all the yearly files into one file
df_abs = pd.DataFrame() #initializes DF which will hold aggregated csv files

for f in glob.glob("*.csv"): #for all csv files in pwd
    df = pd.read_csv(f, low_memory=False) #create dataframe for reading current csv
    df_abs = df_abs.append(df, ignore_index=True) #appends current csv to final DF

# %%
# See what is available (notice we have some whitespaces here)
df_abs.count()
# Out:
# PROJECT_ID    860328
#  ABSTRACT     853082
# dtype: int64

# %%
# Remove Whitespaces
df_abs.rename(columns=lambda x: x.strip(), inplace=True)

# %%
# Make columns lower case
df_abs.columns = map(str.lower, df_abs.columns)

# %%
# Look at the first 5 entries
df_abs.head()
# Out:
#    project_id                                           abstract
# 0      584419  Objective(s): Conduct yearly, accurate nationw...
# 1      584415  Objective(s): Develop new sweetpotato geneotyp...
# 2      584411  Objective(s): The broad objective of this proj...
# 3      584406  Objective(s): The primary goal for this projec...
# 4      584402  Objective(s): Relate effects of hydrothermal t...

# %%
# Save dataframe as csv for data ingestion
# %cd $data_directory_out
df_abs.to_csv('FedExAbs0416.csv')
# Out:
# /gpfs1/cusp/deh341/FederalReporter/out

# %% [markdown]
# # Publication Files

# %% [markdown]
# Here we will have one file for each agency that contains the publication info. We cannot combine that because the data structure is nit the same in each of the data files

# %% [markdown]
# ## From Reporter

# %%
# %cd $data_directory_pub
# Out:
# /gpfs1/cusp/deh341/FederalReporter/publications

# %%
# Append all the yearly files into one file, but here only use NIH files
df_pub_hhs = pd.DataFrame() #initializes DF which will hold aggregated csv files

for f in glob.glob("RePORTER*.csv"): #for all csv files in pwd
    df = pd.read_csv(f, low_memory=False) #create dataframe for reading current csv
    df_pub_hhs = df_pub_hhs.append(df, ignore_index=True) #appends current csv to final DF

# %%
df_pub_hhs.head()
# Out:
#                                          AFFILIATION  \
# 0  Division of Epidemiology, Mayo Clinic College ...
# 1  Department of Molecular and Cellular Biology, ...
# 2  Department of Human Genetics, The University o...
# 3  Laboratory of Environmental and Genetic Toxico...
# 4  Medizinische Hochschule Hannover, Hannover, Ge...
#
#                                          AUTHOR_LIST        COUNTRY  \
# 0  Yang, P; Bamlet, W R; Ebbert, J O; Taylor, W R...        England
# 1  Kleckner, Nancy; Zickler, Denise; Jones, Garet...  United States
# 2  Weiss, Lauren A; Veenstra-Vanderweele, Jeremy;...        England
# 3  Wise, Sandra S; Elmore, Lynne W; Holt, Shawn E...    Netherlands
# 4  Battmer, Rolf D; Dillier, Norbert; Lai, Wai K;...        England
#
#         ISSN JOURNAL_ISSUE                                      JOURNAL_TITLE  \
# 0  0143-3334            10                                     Carcinogenesis
# 1  0027-8424            34  Proceedings of the National Academy of Science...
# 2  1018-4813            11          European journal of human genetics : EJHG
# 3  0300-8177           1-2                Molecular and cellular biochemistry
# 4  1499-2027           NaN                 International journal of audiology
#
#          JOURNAL_TITLE_ABBR JOURNAL_VOLUME LANG PAGE_NUMBER    PMC_ID  \
# 0            Carcinogenesis             25  eng     1935-44       NaN
# 1  Proc Natl Acad Sci U S A            101  eng     12592-7  515102.0
# 2           Eur J Hum Genet             12  eng      949-54       NaN
# 3          Mol Cell Biochem            255  eng      103-11       NaN
# 4              Int J Audiol     43 Suppl 1  eng       S10-5       NaN
#
#        PMID     PUB_DATE                                          PUB_TITLE  \
# 0  15192016     2004 Oct  Glutathione pathway genes and lung cancer risk...
# 1  15299144  2004 Aug 24        A mechanical basis for chromosome function.
# 2  15292919     2004 Nov  Genome-wide association study identifies ITGB3...
# 3  14971651     2004 Jan  Telomerase-mediated lifespan extension of huma...
# 4  15732376     2004 Dec  Evaluation of the neural response telemetry (N...
#
#    PUB_YEAR
# 0      2004
# 1      2004
# 2      2004
# 3      2004
# 4      2004

# %%
# See what is available (notice we have some whitespaces here)
df_pub_hhs.count()
# Out:
# AFFILIATION            868575
# AUTHOR_LIST           1204841
# COUNTRY               1174463
# ISSN                  1193313
# JOURNAL_ISSUE         1082145
# JOURNAL_TITLE         1205036
# JOURNAL_TITLE_ABBR    1205036
# JOURNAL_VOLUME        1189621
# LANG                  1205036
# PAGE_NUMBER           1183554
# PMC_ID                 862179
# PMID                  1205036
# PUB_DATE              1194236
# PUB_TITLE             1204980
# PUB_YEAR              1205036
# dtype: int64

# %%
df_pub_hhs.PUB_YEAR.value_counts()
# Out:
# 2013    112714
# 2014    112397
# 2015    111879
# 2012    108703
# 2011    104253
# 2010     98430
# 2009     93792
# 2016     91589
# 2008     87502
# 2007     78427
# 2006     73052
# 2005     68496
# 2004     63802
# Name: PUB_YEAR, dtype: int64

# %%
# Now we have to get the links to project IDS from the linktable
# %cd $data_directory_key
# Out:
# /gpfs1/cusp/deh341/FederalReporter/key

# %%
# Append all the yearly files into one file, but here only use NIH files
df_pub_key = pd.DataFrame() #initializes DF which will hold aggregated csv files

for f in glob.glob("*.csv"): #for all csv files in pwd
    df = pd.read_csv(f, low_memory=False) #create dataframe for reading current csv
    df_pub_key = df_pub_key.append(df, ignore_index=True) #appends current csv to final DF

# %%
# See what is available (notice we have some whitespaces here)
df_pub_key.count()
# Out:
# PMID               2497774
#  PROJECT_NUMBER    2497774
# dtype: int64

# %%
# Remove Whitespaces
df_pub_key.rename(columns=lambda x: x.strip(), inplace=True)

# %%
df_pub_key.sort_values(by=['PMID'], inplace=True)

# %%
# Check the file
df_pub_key.head()
# Out:
#            PMID PROJECT_NUMBER
# 34372  12576299    R01HL054926
# 34807  12716654    R01AI035796
# 38510  12719981    R01DA013261
# 8088   12730154    P50GM021681
# 20072  12730154    T32GM008593

# %%
# We have duplicates in the file. We are linking the publication to the first Project Number found in FederalReporter only
df_pub_key = df_pub_key.drop_duplicates(subset=['PMID'])

# %%
# Merge to publication dataframe
df_pub_hhs_key = df_pub_hhs.merge(df_pub_key, left_on=['PMID'], right_on=['PMID'], how='left')

# %%
df_pub_hhs_key.count()
# Out:
# AFFILIATION            868575
# AUTHOR_LIST           1204841
# COUNTRY               1174463
# ISSN                  1193313
# JOURNAL_ISSUE         1082145
# JOURNAL_TITLE         1205036
# JOURNAL_TITLE_ABBR    1205036
# JOURNAL_VOLUME        1189621
# LANG                  1205036
# PAGE_NUMBER           1183554
# PMC_ID                 862179
# PMID                  1205036
# PUB_DATE              1194236
# PUB_TITLE             1204980
# PUB_YEAR              1205036
# PROJECT_NUMBER        1054427
# dtype: int64

# %%
# Only keep the ones that have a valid project number because we only can link these
df_pub_hhs_key = df_pub_hhs_key.dropna(subset = ['PROJECT_NUMBER'])

# %%
# Make columns lower case
df_pub_hhs_key.columns = map(str.lower, df_pub_hhs_key.columns)

# %%
df_pub_hhs_key.head()
# Out:
#                                          affiliation  \
# 0  Division of Epidemiology, Mayo Clinic College ...
# 1  Department of Molecular and Cellular Biology, ...
# 2  Department of Human Genetics, The University o...
# 4  Medizinische Hochschule Hannover, Hannover, Ge...
# 5  Institute for Behavioral Research, University ...
#
#                                          author_list        country  \
# 0  Yang, P; Bamlet, W R; Ebbert, J O; Taylor, W R...        England
# 1  Kleckner, Nancy; Zickler, Denise; Jones, Garet...  United States
# 2  Weiss, Lauren A; Veenstra-Vanderweele, Jeremy;...        England
# 4  Battmer, Rolf D; Dillier, Norbert; Lai, Wai K;...        England
# 5  Tinney, Shannon M; Oser, Carrie B; Johnson, J ...  United States
#
#         issn journal_issue                                      journal_title  \
# 0  0143-3334            10                                     Carcinogenesis
# 1  0027-8424            34  Proceedings of the National Academy of Science...
# 2  1018-4813            11          European journal of human genetics : EJHG
# 4  1499-2027           NaN                 International journal of audiology
# 5  1094-3412             4  The journal of behavioral health services & re...
#
#          journal_title_abbr journal_volume lang page_number    pmc_id  \
# 0            Carcinogenesis             25  eng     1935-44       NaN
# 1  Proc Natl Acad Sci U S A            101  eng     12592-7  515102.0
# 2           Eur J Hum Genet             12  eng      949-54       NaN
# 4              Int J Audiol     43 Suppl 1  eng       S10-5       NaN
# 5   J Behav Health Serv Res             31  eng      403-17       NaN
#
#        pmid      pub_date                                          pub_title  \
# 0  15192016      2004 Oct  Glutathione pathway genes and lung cancer risk...
# 1  15299144   2004 Aug 24        A mechanical basis for chromosome function.
# 2  15292919      2004 Nov  Genome-wide association study identifies ITGB3...
# 4  15732376      2004 Dec  Evaluation of the neural response telemetry (N...
# 5  15602141  2004 Oct-Dec  Predominantly female caseloads: identifying or...
#
#    pub_year project_number
# 0      2004    R01CA080127
# 1      2004    R01HG003143
# 2      2004    R01HG001645
# 4      2004    P50DC000242
# 5      2004    R01DA013110

# %%
# Save dataframe as csv for data ingestion
# %cd $data_directory_out
df_pub_hhs_key.to_csv('FedExPubHHS0416.csv')
# Out:
# /gpfs1/cusp/deh341/FederalReporter/out

# %% [markdown]
# ## From Federal Reporter

# %% [markdown]
# Now we can just do this with the other Publication data as well. We will keep them in each in their own file

# %%
# %cd $data_directory_pub
# Out:
# /gpfs1/cusp/deh341/FederalReporter/publications

# %%
# Append all the yearly files into one file, but here only use NIH files
df_pub_other = pd.DataFrame() #initializes DF which will hold aggregated csv files

for f in glob.glob("FedRePORTER*.csv"): #for all csv files in pwd
    df = pd.read_csv(f, low_memory=False, error_bad_lines=False) #create dataframe for reading current csv
    df_pub_other = df_pub_other.append(df, ignore_index=True) #appends current csv to final DF
# Out:
# b'Skipping line 285: expected 3 fields, saw 12\nSkipping line 1437: expected 3 fields, saw 4\nSkipping line 3588: expected 3 fields, saw 5\nSkipping line 5287: expected 3 fields, saw 5\nSkipping line 7092: expected 3 fields, saw 5\nSkipping line 9873: expected 3 fields, saw 5\n'
# b'Skipping line 341: expected 3 fields, saw 7\nSkipping line 626: expected 3 fields, saw 7\nSkipping line 680: expected 3 fields, saw 7\nSkipping line 777: expected 3 fields, saw 8\nSkipping line 837: expected 3 fields, saw 11\nSkipping line 1239: expected 3 fields, saw 9\nSkipping line 1354: expected 3 fields, saw 7\nSkipping line 1355: expected 3 fields, saw 7\nSkipping line 1375: expected 3 fields, saw 7\nSkipping line 1376: expected 3 fields, saw 7\nSkipping line 1403: expected 3 fields, saw 8\nSkipping line 1445: expected 3 fields, saw 13\nSkipping line 1531: expected 3 fields, saw 6\nSkipping line 1532: expected 3 fields, saw 6\nSkipping line 1753: expected 3 fields, saw 6\nSkipping line 1754: expected 3 fields, saw 7\nSkipping line 1921: expected 3 fields, saw 7\nSkipping line 1922: expected 3 fields, saw 7\nSkipping line 1951: expected 3 fields, saw 5\nSkipping line 1957: expected 3 fields, saw 7\nSkipping line 1958: expected 3 fields, saw 7\nSkipping line 2022: expected 3 fields, saw 7\nSkipping line 2155: expected 3 fields, saw 9\nSkipping line 2175: expected 3 fields, saw 8\nSkipping line 2176: expected 3 fields, saw 8\nSkipping line 2215: expected 3 fields, saw 7\nSkipping line 2490: expected 3 fields, saw 7\nSkipping line 2515: expected 3 fields, saw 9\nSkipping line 2679: expected 3 fields, saw 4\nSkipping line 3009: expected 3 fields, saw 6\nSkipping line 3038: expected 3 fields, saw 9\nSkipping line 3039: expected 3 fields, saw 7\nSkipping line 3142: expected 3 fields, saw 8\nSkipping line 3586: expected 3 fields, saw 8\nSkipping line 3630: expected 3 fields, saw 7\nSkipping line 3749: expected 3 fields, saw 8\nSkipping line 4172: expected 3 fields, saw 9\nSkipping line 4300: expected 3 fields, saw 7\nSkipping line 4312: expected 3 fields, saw 8\nSkipping line 4559: expected 3 fields, saw 10\nSkipping line 4654: expected 3 fields, saw 8\nSkipping line 4756: expected 3 fields, saw 13\nSkipping line 5100: expected 3 fields, saw 7\nSkipping line 5231: expected 3 fields, saw 9\nSkipping line 5258: expected 3 fields, saw 10\nSkipping line 5647: expected 3 fields, saw 8\nSkipping line 6093: expected 3 fields, saw 4\nSkipping line 6155: expected 3 fields, saw 7\nSkipping line 6290: expected 3 fields, saw 10\nSkipping line 6346: expected 3 fields, saw 7\nSkipping line 6430: expected 3 fields, saw 7\nSkipping line 6467: expected 3 fields, saw 7\nSkipping line 6498: expected 3 fields, saw 6\nSkipping line 6830: expected 3 fields, saw 6\nSkipping line 7068: expected 3 fields, saw 8\nSkipping line 7297: expected 3 fields, saw 11\nSkipping line 7375: expected 3 fields, saw 8\nSkipping line 7384: expected 3 fields, saw 9\nSkipping line 7607: expected 3 fields, saw 7\nSkipping line 7721: expected 3 fields, saw 9\nSkipping line 7723: expected 3 fields, saw 9\nSkipping line 7954: expected 3 fields, saw 5\nSkipping line 8159: expected 3 fields, saw 7\nSkipping line 8549: expected 3 fields, saw 7\nSkipping line 8550: expected 3 fields, saw 8\nSkipping line 8551: expected 3 fields, saw 7\nSkipping line 8552: expected 3 fields, saw 8\nSkipping line 8553: expected 3 fields, saw 7\nSkipping line 8554: expected 3 fields, saw 7\nSkipping line 8555: expected 3 fields, saw 8\nSkipping line 8556: expected 3 fields, saw 7\nSkipping line 8557: expected 3 fields, saw 8\nSkipping line 8558: expected 3 fields, saw 8\nSkipping line 8559: expected 3 fields, saw 7\nSkipping line 8560: expected 3 fields, saw 7\nSkipping line 8561: expected 3 fields, saw 7\nSkipping line 8562: expected 3 fields, saw 8\nSkipping line 8563: expected 3 fields, saw 7\nSkipping line 8564: expected 3 fields, saw 7\nSkipping line 8565: expected 3 fields, saw 7\nSkipping line 8830: expected 3 fields, saw 8\nSkipping line 8837: expected 3 fields, saw 7\nSkipping line 9015: expected 3 fields, saw 7\nSkipping line 9900: expected 3 fields, saw 8\nSkipping line 10182: expected 3 fields, saw 8\nSkipping line 10227: expected 3 fields, saw 7\nSkipping line 10316: expected 3 fields ...

# %%
df_pub_other.count()
# Out:
# COMMON_PROJECT_NUMBER    552510
#  TITLE                   552415
#  AUTHORS_LIST            551525
# dtype: int64

# %%
# Remove Whitespaces
df_pub_other.rename(columns=lambda x: x.strip(), inplace=True)
# Make columns lower case
df_pub_other.columns = map(str.lower, df_pub_other.columns)
# Rename identifier
df_pub_other.rename(columns={'common_project_number': 'project_number'}, inplace=True)

# %%
df_pub_other.head()
# Out:
#   project_number                                              title  \
# 0    ARS-0422661  Calibration and validation of the SWAT model f...
# 1    ARS-0423023  The draft genome of whitefly Bemisia tabaci ME...
# 2    ARS-0422661  Spatial uniformity in sensitivity coefficient ...
# 3    ARS-0422661  Soil heat flux calculation for sunlit and shad...
# 4    ARS-0423057  Bioassay conditions for infection of Pinus rad...
#
#                                         authors_list
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Paul D. Colaizzi;Steven R. Evett;Nurit Agam;Ro...
# 4                 Timothy L. Widmer;Stephen C. Dodge

# %%
# Save dataframe as csv for data ingestion
# %cd $data_directory_out
df_pub_other.to_csv('FedExPubOTH0416.csv')
# Out:
# /gpfs1/cusp/deh341/FederalReporter/out

# %% [markdown]
# # Load data in Database

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql:///ada_pub')# ingest publications to database

# %%
# ingest publications from Reporter to database
df_pub_hhs_key.to_sql('publications_hhs', engine, index=False, if_exists='replace')

# %%
# ingest publications from Federal Reporter to database
df_pub_other.to_sql('publications_other', engine, index=False, if_exists='replace')

# %%
# ingest publications to database
df_abs.to_sql('abstracts', engine, index=False, if_exists='replace')

# %%
# ingest publications to database
df_prj.to_sql('projects', engine, index=False, if_exists='replace')

# %% [markdown]
# # Test queries

# %%
# Use pandas
a=pd.read_sql_query('select * FROM projects',con=engine)
a.head()

# %%
b=pd.read_sql_query('select * FROM abstracts',con=engine)
b.head()

# %%
c=pd.read_sql_query('select * FROM publications_hhs',con=engine)
c.head()

# %%
d=pd.read_sql_query('select * FROM publications_other',con=engine)
d

# %%
# Use sqlalchmey
sql_string = "SELECT COUNT( * ) AS row_count FROM projects;"
query_result = engine.execution_options( stream_results = True ).execute( sql_string )
result_list = query_result.fetchall()
result_list
