# %% [markdown]
# # Web scraping
#
# **Date: 28 March 2017**
#
# @author: Daniel Csaba

# %% [markdown]
# ## Preliminaries
#
# Import usual packages.

# %%
import pandas as pd             # data package
import matplotlib.pyplot as plt # graphics 
import datetime as dt           # date tools, used to note current date  

# %matplotlib inline

# %% [markdown]
# We have seen how to input data from `csv` and `xls` files -- either online or from our computer and through APIs. Sometimes the data is only available as specific part of a website.
#
# We want to access the source code of the website and systematically extract the relevant information.

# %% [markdown]
# Again, use Google fu to find useful links. Here are a couple:
# * [link 1](https://www.dataquest.io/blog/web-scraping-tutorial-python/)
# * [link 2](http://blog.danwin.com/examples-of-web-scraping-in-python-3-x-for-data-journalists/)
# * [link 3](https://www.analyticsvidhya.com/blog/2015/10/beginner-guide-web-scraping-beautiful-soup-python/)

# %% [markdown]
# ## Structure of web pages (very simplistic)
#
# `Hypertext Markup Language` (HTML) specifies the structure and main content of the site -- tells the browser how to layout content. Think of `Markdown`.
#
# It is structured using tags.
#
# ```html
# <html>
#     <head>
#         (Meta) Information about the page.
#     </head>
#     <body>
#         <p>
#             This is a paragraph.
#         </p>
#         <table>
#             This is a table
#         </table>
#     </body>
# </html>
# ```

# %% [markdown]
# `Tag`s determine the content and layout depending on their relation to other tags. Useful terminology:
#
# * `child` -- a child is a tag inside another tag. The `p` tag above is a child of the `body` tag.
# * `parent` --  a parent is the tag another tag is inside. The `body` tag above is a parent of the `p` tag.
# * `sibling` -- a sibling is a tag that is nested inside the same parent as another tag. The `head` and `body` tags above are siblings.
#
# There are many different tags -- take a look at a [reference list](https://developer.mozilla.org/en-US/docs/Web/HTML/Element). You won't and shouldn't remember all of them but it's useful to have a rough idea about them.
#
# And take a look at a real example -- open page, then right click:  "View Page Source"

# %% [markdown]
# In the real example you will see that there is more information after the tag, most commanly a `class` and an `id`. Something similar to the following:
#
# ```html
# <html>
#     <head class='main-head'>
#         (Meta) Information about the page.
#     </head>
#     <body>
#         <p class='inner-paragraph' id='001'>
#             This is a paragraph.
#         </p>
#         <table class='inner-table' id='002'>
#             This is a table
#         </table>
#     </body>
# </html>
# ```
# The `class` and `id` information will help us in locating the information we are looking for in a systematic way.
#
# Useful way to explore the `html` and the corresponding website is right clicking on the web page and then clicking on `Inspect element` -- interpretation of the html by the browser

# %% [markdown]
# Suppose we want to check prices for renting a room in Manhattan in Craigslist. Let's check for example the `rooms & shares` section for the [East Village](https://newyork.craigslist.org/search/roo?query=east+village&availabilityMode=0).

# %% [markdown]
# ## Accessing web pages
#
# We have to download the content of the webpage -- i.e. get the contents structured by the HTML. This we can do with the `requests` library, which is a human readable HTTP (HyperText Transfer Protocol) library for python. You cna find the Quickstart Documentation [here](http://docs.python-requests.org/en/master/user/quickstart/).

# %%
import requests

# %% [markdown]
# You might want to query for different things and download information for all of them. You can pass this as extra information.

# %%
# see if the URL was specified successfully
url = 'https://newyork.craigslist.org/search/roo?query=east+village&availabilityMode=0'
cl = requests.get(url)

# %%
type(cl)
# Out:
# requests.models.Response

# %%
cl
# Out:
# <Response [200]>

# %% [markdown]
# The `[200]` stands for the `status_code` which carries information whether the download was succesful. If it starts with 2 it's a good sign, 4 or 5 not so much.

# %%
cl.status_code
# Out:
# 200

# %% [markdown]
# Check tab completion

# %%
cl.url
# Out:
# 'https://newyork.craigslist.org/search/roo?query=east+village&availabilityMode=0'

# %% [markdown]
# This is going to be ugly and unreadable -- get the text, or general content.

# %%
cl.content
# Out:
# b'\xef\xbb\xbf<!DOCTYPE html>\n\n<html class="no-js"><head>\n    <title>new york rooms for rent &amp; shares available &quot;east village&quot; - craigslist</title>\n\n    <meta name="description" content="new york rooms for rent &amp; shares available &quot;east village&quot; - craigslist">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <link rel="canonical" href="https://newyork.craigslist.org/search/roo">\n    <link rel="alternate" type="application/rss+xml" href="https://newyork.craigslist.org/search/roo?availabilityMode=0&amp;format=rss&amp;query=east%20village" title="RSS feed for craigslist | new york rooms for rent &amp; shares available &quot;east village&quot; - craigslist ">\n    \n    <link rel="next" href="https://newyork.craigslist.org/search/roo?s=120&amp;availabilityMode=0&amp;query=east%20village">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=a14d0c65f7978c2bbc0d780a3ea7b7be">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=27e1d4246df60da5ffd1146d59a8107e">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n    <link rel="prefetch" href="//www.craigslist.org/js/postings-concat.min.js?v=0903dc7c0cd2012bde76ced037661005">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=a3659216b188171f9645f20cd0b4e60e">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=0643bce4a898776e6e10a86823bab509">\n<!--[if IE]>\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">\n<![endif]-->\n    \n        <script type="text/javascript"><!--\nvar areaCountry = "US";\nvar areaID = "3";\nvar areaRegion = "NY";\nvar catAbb = "roo";\nvar countOfTotalText = "image {count} of {total}";\nvar currencySymbol = "&#x0024;";\nvar defaultView = "list";\nvar expiredFavIDs = null;\nvar imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\nvar lessInfoText = "less info";\nvar maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\nvar maxResults = 2500;\nvar noImageText = "no image";\nvar pID = null;\nvar postalLat = null;\nvar postalLon = null;\nvar purveyorCategories = null;\nvar searchDistance = null;\nvar sectionAbb = "hhh";\nvar sectionBase = "hhh";\nvar showInfoText = "show info";\nvar showMapTabs = 1;\nvar showingBanished = 0;\nvar showingFavorites = 0;\nvar starHint = "save this post in your favorites list";\nvar subarea = null;\nvar zoomToPosting = null;\n--></script>\n    \n    <!--[if lt IE 9]>\n<script src="//www.craigslist.org/js/html5shiv.min.js?v=c0739b14a84b052680cdee44fea07435" type="text/javascript" ></script>\n\n<script src="//www.craigslist.org/js/respond-fork.min.js?v=247e877d69233f6f77bff30aca7b5473" type="text/javascript" ></script>\n\n<![endif]-->\n<!--[if lte IE 7]>\n<script src="//www.craigslist.org/js/json2.min.js?v=6e47a4bb061d538548771024390aa00b" type="text/javascript" ></script>\n\n<![endif]-->\n</head>\n<body class="search has-map en">\n    <script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no-js\', \'js\');\n        var b = document.body;\n  ...

# %%
# this is another way to specify the URL
url= 'https://newyork.craigslist.org/search/roo'
keys = {'query':['east village', 'west village'],'availabilityMode':'0'}
cl_extra = requests.get(url, params=keys)

# %%
cl_extra.status_code
# Out:
# 200

# %%
cl_extra.url
# Out:
# 'https://newyork.craigslist.org/search/roo?query=east+village&query=west+village&availabilityMode=0'

# %%
cl_extra.content
# Out:
# b'\xef\xbb\xbf<!DOCTYPE html>\n\n<html class="no-js"><head>\n    <title>new york rooms for rent &amp; shares available &quot;east village&quot; - craigslist</title>\n\n    <meta name="description" content="new york rooms for rent &amp; shares available &quot;east village&quot; - craigslist">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <link rel="canonical" href="https://newyork.craigslist.org/search/roo">\n    <link rel="alternate" type="application/rss+xml" href="https://newyork.craigslist.org/search/roo?availabilityMode=0&amp;format=rss&amp;query=east%20village&amp;query=west%20village" title="RSS feed for craigslist | new york rooms for rent &amp; shares available &quot;east village&quot; - craigslist ">\n    \n    <link rel="next" href="https://newyork.craigslist.org/search/roo?s=120&amp;availabilityMode=0&amp;query=east%20village&amp;query=west%20village">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=a14d0c65f7978c2bbc0d780a3ea7b7be">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=27e1d4246df60da5ffd1146d59a8107e">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n    <link rel="prefetch" href="//www.craigslist.org/js/postings-concat.min.js?v=0903dc7c0cd2012bde76ced037661005">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=a3659216b188171f9645f20cd0b4e60e">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=0643bce4a898776e6e10a86823bab509">\n<!--[if IE]>\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">\n<![endif]-->\n    \n        <script type="text/javascript"><!--\nvar areaCountry = "US";\nvar areaID = "3";\nvar areaRegion = "NY";\nvar catAbb = "roo";\nvar countOfTotalText = "image {count} of {total}";\nvar currencySymbol = "&#x0024;";\nvar defaultView = "list";\nvar expiredFavIDs = null;\nvar imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\nvar lessInfoText = "less info";\nvar maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\nvar maxResults = 2500;\nvar noImageText = "no image";\nvar pID = null;\nvar postalLat = null;\nvar postalLon = null;\nvar purveyorCategories = null;\nvar searchDistance = null;\nvar sectionAbb = "hhh";\nvar sectionBase = "hhh";\nvar showInfoText = "show info";\nvar showMapTabs = 1;\nvar showingBanished = 0;\nvar showingFavorites = 0;\nvar starHint = "save this post in your favorites list";\nvar subarea = null;\nvar zoomToPosting = null;\n--></script>\n    \n    <!--[if lt IE 9]>\n<script src="//www.craigslist.org/js/html5shiv.min.js?v=c0739b14a84b052680cdee44fea07435" type="text/javascript" ></script>\n\n<script src="//www.craigslist.org/js/respond-fork.min.js?v=247e877d69233f6f77bff30aca7b5473" type="text/javascript" ></script>\n\n<![endif]-->\n<!--[if lte IE 7]>\n<script src="//www.craigslist.org/js/json2.min.js?v=6e47a4bb061d538548771024390aa00b" type="text/javascript" ></script>\n\n<![endif]-->\n</head>\n<body class="search has-map en">\n    <script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no ...

# %% [markdown]
# ## Extracting information from a web page
#
# Now that we have the content of the web page we want to extraxt certain information. `BeautifulSoup` is a Python package which helps us in doing that. See the [documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) for more information.

# %%
from bs4 import BeautifulSoup

# %%
BeautifulSoup?

# %%
# parse the html
cl_soup = BeautifulSoup(cl.content,'html.parser')

# %% [markdown]
# Print this out in a prettier way.

# %%
print(cl_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    new york rooms for rent &amp; shares available "east village" - craigslist
#   </title>
#   <meta content='new york rooms for rent &amp; shares available "east village" - craigslist' name="description">
#    <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#    <link href="https://newyork.craigslist.org/search/roo" rel="canonical">
#     <link href="https://newyork.craigslist.org/search/roo?availabilityMode=0&amp;format=rss&amp;query=east%20village" rel="alternate" title='RSS feed for craigslist | new york rooms for rent &amp; shares available "east village" - craigslist ' type="application/rss+xml">
#      <link href="https://newyork.craigslist.org/search/roo?s=120&amp;availabilityMode=0&amp;query=east%20village" rel="next">
#       <meta content="width=device-width,initial-scale=1" name="viewport">
#        <link href="//www.craigslist.org/styles/cl.css?v=a14d0c65f7978c2bbc0d780a3ea7b7be" media="all" rel="stylesheet" type="text/css">
#         <link href="//www.craigslist.org/styles/search.css?v=27e1d4246df60da5ffd1146d59a8107e" media="all" rel="stylesheet" type="text/css">
#          <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css">
#           <link href="//www.craigslist.org/js/postings-concat.min.js?v=0903dc7c0cd2012bde76ced037661005" rel="prefetch">
#            <link href="//www.craigslist.org/styles/leaflet.css?v=a3659216b188171f9645f20cd0b4e60e" media="all" rel="stylesheet" type="text/css">
#             <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css">
#              <link href="//www.craigslist.org/styles/tocsmaps.css?v=0643bce4a898776e6e10a86823bab509" media="all" rel="stylesheet" type="text/css">
#               <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#               <script type="text/javascript">
#                <!--
# var areaCountry = "US";
# var areaID = "3";
# var areaRegion = "NY";
# var catAbb = "roo";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "list";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 2500;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = null;
# var searchDistance = null;
# var sectionAbb = "hhh";
# var sectionBase = "hhh";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# -->
#               </script>
#               <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=c0739b14a84b052680cdee44fea07435" type="text/javascript" ></script>
#
# <script src="//www.craigslist.org/js/respond-fork.min.js?v=247e877d69233f6f77bff30aca7b5473" type="text/javascript" ></script>
#
# <![endif]-->
#               <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=6e47a4bb061d538548771024390aa00b" type="text/javascript" ></script>
#
# <![endif]-->
#              </link>
#             </link>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </meta>
#      </link>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="search has-map en">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section class="page-container" id="page-top">
#    <div class="bglogo">
#    </div>
#    <header class="global-header">
#     <a class="header-logo" href="/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/roo" class="breadcrumbs-form" data-action="/search/###/roo" id="breadcrumbform" method="get">
#       <input name="query" type="hidden" value="east village">
#        <ul class="breadcrumbs ">
#         <li class="crumb area">
#          <span class="no-js">
#           <a href="/">
#            new york
#           </a>
#          </span>
#          <select class="js-only" id="areaAbb" name="areaAbb">
#           <option value="newyork">
#            new york
#           </option>
#           <option value="albany">
#            albany, NY
#           </option>
#           <option value="allentown">
#            allentown
#           </option>
#           <option value="altoona">
#            altoona
#           </option>
#           <option value="annapolis">
#            annapolis
#           </option>
#           <option value="baltimore">
#            baltimore
#           </option>
#           <option value="binghamton">
#            binghamton
#           </option>
#           <option value="boston">
#            boston
#           </option>
#           <option value="capecod">
#            cape cod
#           </option>
#           <option value="catskills">
#            catskills
#           </option>
#           <option value="cnj">
#            central NJ
#           </option>
#           <option value="chambersburg">
#            cumberland val
#           </option>
#           <option value="delaware">
#            delaware
#           </option>
#           <option value="newlondon">
#            eastern CT
#           </option>
#           <option value="easternshore">
#            eastern shore
#           </option>
#           <option value="martinsburg">
#            eastern WV
#           </option>
#           <option value="elmira">
#            elmira
#           </option>
#           <option value="fingerlakes">
#            finger lakes
#           </option>
#           <option value="frederick">
#            frederick
#           </option>
#           <option value="glensfalls">
#            glens falls
#           </option>
#           <option value="harrisburg">
#            harrisburg
#           </option>
#           <option value="hartford">
#            hartford
#           </option>
#           <option value="hudsonvalley">
#            hudson valley
#           </option>
#           <option value="ithaca">
#            ithaca
#           </option>
#           <option value="jerseyshore">
#            jersey shore
#           </option>
#           <option value="lancaster">
#            lancaster, PA
#           </option>
#           <option value="longisland">
#            long island
#           </option>
#           <option value="newhaven">
#            new haven
#           </option>
#           <option value="newjersey">
#            north jersey
#           </option>
#           <option value="nwct">
#            northwest CT
#           </option>
#           <option value="oneonta">
#            oneonta
#           </option>
#           <option value="philadelphia">
#            philadelphia
#           </option>
#           <option value="poconos">
#            poconos
#           </option>
#           <option value="reading">
#            reading
#           </option>
#           <option value="providence">
#            rhode island
#           </option>
#           <option value="scranton">
#            scranton
#           </option>
#           <option value="southcoast">
#            south coast
#           </option>
#           <option value="southjersey">
#            south jersey
#           </option>
#           <option value="smd">
#            southern MD
#           </option>
#           <option value="pennstate">
#            state college
#           </option>
#           <option value="syracuse">
#            syracuse
#           </option>
#           <option value="utica">
#            utica
#           </option>
#           <option value="washingtondc">
#            washington, DC
#           </option>
#           <option value="westernmass">
#            western mass
#           </option>
#           <option value="williamsport">
#            williamsport
#           </option>
#           <option value="worcester">
#            worcester
#           </option>
#           <option value="york">
#            york, PA
#           </option>
#          </select>
#          <span class="breadcrumb-arrow">
#           &gt;
#          </span>
#         </li>
#         <li class="crumb subarea">
#          <select id="subArea" name="subArea">
#           <option selected="" value="">
#            all new york
#           </option>
#           <option value="brx">
#            bronx
#           </option>
#           <option value="brk">
#            brooklyn
#           </option>
#           <option value="fct">
#            fairfield
#           </option>
#           <option value="lgi">
#            long island
#           </option>
#           <option value="mnh">
#            manhattan
#           </option>
#           <option value="jsy">
#            new jersey
#           </option>
#           <option value="que">
#            queens
#           </option>
#           <option value="stn">
#            staten island
#           </option>
#           <option value="wch">
#            westchester
#           </option>
#          </select>
#          <span class="breadcrumb-arrow">
#           &gt;
#          </span>
#         </li>
#         <li class="crumb section">
#          <select id="catAbb" name="catAbb">
#           <option value="ccc">
#            community
#           </option>
#           <option value="eee">
#            events
#           </option>
#           <option value="sss">
#            for sale
#           </option>
#           <option value="ggg">
#            gigs
#           </option>
#           <option selected="" value="hhh">
#            housing
#           </option>
#           <option value="jjj">
#            jobs
#           </option>
#           <option value="ppp">
#            personals
#           </option>
#           <option value="rrr">
#            resumes
#           </option>
#           <option value="bbb">
#            services
#           </option>
#          </select>
#          <span class="breadcrumb-arrow">
#           &gt;
#          </span>
#         </li>
#         <li class="crumb category">
#          <select class="js-only" id="subcatAbb">
#           <option value="hhh">
#            all
#           </option>
#           <option value="fee">
#            apts broker fee
#           </option>
#           <option value="nfb">
#            apts broker no fee
#           </option>
#           <option value="abo">
#            apts by owner
#           </option>
#           <option value="aiv">
#            apts registration fee
#           </option>
#           <option value="hou">
#            apts wanted
#           </option>
#           <option value="swp">
#            housing swap
#           </option>
#           <option value="off">
#            office &amp; commercial
#           </option>
#           <option value="prk">
#            parking &amp; storage
#           </option>
#           <option value="reb">
#            real estate - by broker
#           </option>
#           <option value="reo">
#            real estate - by owner
#           </option>
#           <option value="rew">
#            real estate wanted
#           </option>
#           <option selected="" value="roo">
#            rooms &amp; shares
#           </option>
#           <option value="sha">
#            rooms wanted
#           </option>
#           <option value="sbw">
#            sublet/temp wanted
#           </option>
#           <option value="sub">
#            sublets &amp; temporary
#           </option>
#           <option value="vac">
#            vacation rentals
#           </option>
#          </select>
#          <span class="no-js">
#           rooms &amp; shares
#          </span>
#          <span class="breadcrumb-arrow">
#           &gt;
#          </span>
#         </li>
#         <li class="crumb no-js">
#          <input type="submit" value="go">
#          </input>
#         </li>
#        </ul>
#       </input>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/nyc">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <form action="/favorites" class="unfavform js-only" method="POST">
#         <div class="to-banish-page">
#          <input class="lastLink" name="lastLink" type="hidden" value="//newyork.craigslist.org/search/roo?availabilityMode=0&amp;query=east%20village">
#           <input class="lastTitle" name="lastTitle" type="hidden" value='new york rooms for rent &amp; shares available "east village" - craigslist'>
#            <input class="unfaves" name="fl" type="hidden">
#             <input name="uf" type="hidden" value="1">
#              <a class="to-banish-page-link" href="#">
#               <span aria-hidden="true" class="icon icon-trash red">
#               </span>
#               <span class="banished_count">
#                0
#               </span>
#               <span class="discards-label">
#                hidden
#               </span>
#              </a>
#             </input>
#            </input>
#           </input>
#          </input>
#         </div>
#        </form>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <form action="/search/roo" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search rooms for rent &amp; shares available" type="text" value="east village">
#       <button class="searchbtn" type="submit">
#        <span aria-hidden="true" class="icon icon-search">
#        </span>
#        <span class="screen-reader-text">
#         press to search craigslist
#        </span>
#       </button>
#       <div class="savealert">
#        <a class="saveme" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fnewyork%252Ecraigslist%252Eorg%252Fsearch%252Froo%253FavailabilityMode%253D0%2526query%253Deast%252520village" title="save this search">
#         save search
#        </a>
#       </div>
#      </input>
#     </div>
#     <div class="search-options-container">
#      <h2 class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </h2>
#      <input id="excats" name="excats" type="hidden">
#       <div class="search-options">
#        <div class="searchgroup categories">
#         <div class="cattitle">
#          <a class="reset" href="/search/roo" title="clear all search parameters">
#           rooms for rent &amp; shares available
#          </a>
#         </div>
#        </div>
#        <input name="userid" type="hidden" value=""/>
#        <div class="searchgroup">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input name="srchType" type="checkbox" value="T">
#             search titles only
#            </input>
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1">
#             has image
#            </input>
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1">
#             posted today
#            </input>
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1">
#             bundle duplicates
#            </input>
#           </label>
#          </li>
#          <li>
#           <label class="searchNearby">
#            <input class="autosubmit" name="searchNearby" type="checkbox" value="1">
#             include nearby areas
#            </input>
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas ">
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_20" name="nearbyArea" type="checkbox" value="59"/>
#            albany, NY
#            <small>
#             (alb)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_45" name="nearbyArea" type="checkbox" value="355"/>
#            altoona-johnstown
#            <small>
#             (aoo)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_33" name="nearbyArea" type="checkbox" value="460"/>
#            annapolis, MD
#            <small>
#             (anp)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_28" name="nearbyArea" type="checkbox" value="34"/>
#            baltimore, MD
#            <small>
#             (bal)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_60" name="nearbyArea" type="checkbox" value="483"/>
#            belleville, ON
#            <small>
#             (bel)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_21" name="nearbyArea" type="checkbox" value="248"/>
#            binghamton, NY
#            <small>
#             (bgm)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_35" name="nearbyArea" type="checkbox" value="4"/>
#            boston
#            <small>
#             (bos)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_58" name="nearbyArea" type="checkbox" value="40"/>
#            buffalo, NY
#            <small>
#             (buf)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_42" name="nearbyArea" type="checkbox" value="239"/>
#            cape cod / islands
#            <small>
#             (cap)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_9" name="nearbyArea" type="checkbox" value="451"/>
#            catskills
#            <small>
#             (cat)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_2" name="nearbyArea" type="checkbox" value="349"/>
#            central NJ
#            <small>
#             (cnj)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_63" name="nearbyArea" type="checkbox" value="290"/>
#            charlottesville, VA
#            <small>
#             (uva)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_62" name="nearbyArea" type="checkbox" value="452"/>
#            chautauqua, NY
#            <small>
#             (chq)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_61" name="nearbyArea" type="checkbox" value="481"/>
#            cornwall, ON
#            <small>
#             (ycc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_38" name="nearbyArea" type="checkbox" value="705"/>
#            cumberland valley
#            <small>
#             (cbg)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_19" name="nearbyArea" type="checkbox" value="193"/>
#            delaware
#            <small>
#             (dlw)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_15" name="nearbyArea" type="checkbox" value="281"/>
#            eastern CT
#            <small>
#             (nlo)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_44" name="nearbyArea" type="checkbox" value="444"/>
#            eastern panhandle
#            <small>
#             (ewv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_29" name="nearbyArea" type="checkbox" value="328"/>
#            eastern shore
#            <small>
#             (esh)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_30" name="nearbyArea" type="checkbox" value="453"/>
#            elmira-corning
#            <small>
#             (elm)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_36" name="nearbyArea" type="checkbox" value="685"/>
#            finger lakes, NY
#            <small>
#             (fgl)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_39" name="nearbyArea" type="checkbox" value="633"/>
#            frederick, MD
#            <small>
#             (fdk)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_49" name="nearbyArea" type="checkbox" value="457"/>
#            fredericksburg, VA
#            <small>
#             (ezf)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_34" name="nearbyArea" type="checkbox" value="686"/>
#            glens falls, NY
#            <small>
#             (gfl)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_59" name="nearbyArea" type="checkbox" value="48"/>
#            hampton roads
#            <small>
#             (nfk)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_23" name="nearbyArea" type="checkbox" value="166"/>
#            harrisburg, PA
#            <small>
#             (hrs)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_64" name="nearbyArea" type="checkbox" value="447"/>
#            harrisonburg, VA
#            <small>
#             (shd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_12" name="nearbyArea" type="checkbox" value="44"/>
#            hartford, CT
#            <small>
#             (htf)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_4" name="nearbyArea" type="checkbox" value="249"/>
#            hudson valley, NY
#            <small>
#             (hud)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_31" name="nearbyArea" type="checkbox" value="201"/>
#            ithaca, NY
#            <small>
#             (ith)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_1" name="nearbyArea" type="checkbox" value="561"/>
#            jersey shore
#            <small>
#             (jys)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_54" name="nearbyArea" type="checkbox" value="385"/>
#            kingston, ON
#            <small>
#             (kng)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_17" name="nearbyArea" type="checkbox" value="279"/>
#            lancaster, PA
#            <small>
#             (lns)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_7" name="nearbyArea" type="checkbox" value="167"/>
#            lehigh valley
#            <small>
#             (alt)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_3" name="nearbyArea" type="checkbox" value="250"/>
#            long island, NY
#            <small>
#             (isp)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_46" name="nearbyArea" type="checkbox" value="198"/>
#            new hampshire
#            <small>
#             (nhm)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_5" name="nearbyArea" type="checkbox" value="168"/>
#            new haven, CT
#            <small>
#             (hvn)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_0" name="nearbyArea" type="checkbox" value="170"/>
#            north jersey
#            <small>
#             (njy)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_10" name="nearbyArea" type="checkbox" value="354"/>
#            northwest CT
#            <small>
#             (nct)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_18" name="nearbyArea" type="checkbox" value="684"/>
#            oneonta, NY
#            <small>
#             (onh)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_8" name="nearbyArea" type="checkbox" value="17"/>
#            philadelphia
#            <small>
#             (phi)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_55" name="nearbyArea" type="checkbox" value="338"/>
#            plattsburgh-adirondacks
#            <small>
#             (plb)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_6" name="nearbyArea" type="checkbox" value="356"/>
#            poconos
#            <small>
#             (poc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_56" name="nearbyArea" type="checkbox" value="683"/>
#            potsdam-canton-massena
#            <small>
#             (ptd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_14" name="nearbyArea" type="checkbox" value="278"/>
#            reading, PA
#            <small>
#             (rea)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_24" name="nearbyArea" type="checkbox" value="38"/>
#            rhode island
#            <small>
#             (prv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_57" name="nearbyArea" type="checkbox" value="60"/>
#            richmond, VA
#            <small>
#             (ric)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_50" name="nearbyArea" type="checkbox" value="126"/>
#            rochester, NY
#            <small>
#             (rcs)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_11" name="nearbyArea" type="checkbox" value="276"/>
#            scranton / wilkes-barre
#            <small>
#             (avp)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_27" name="nearbyArea" type="checkbox" value="378"/>
#            south coast, MA
#            <small>
#             (sma)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_13" name="nearbyArea" type="checkbox" value="286"/>
#            south jersey
#            <small>
#             (snj)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_43" name="nearbyArea" type="checkbox" value="556"/>
#            southern maryland
#            <small>
#             (smd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_40" name="nearbyArea" type="checkbox" value="277"/>
#            state college, PA
#            <small>
#             (psu)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_37" name="nearbyArea" type="checkbox" value="130"/>
#            syracuse, NY
#            <small>
#             (syr)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_53" name="nearbyArea" type="checkbox" value="704"/>
#            twin tiers NY/PA
#            <small>
#             (tts)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_32" name="nearbyArea" type="checkbox" value="247"/>
#            utica-rome-oneida
#            <small>
#             (uti)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_52" name="nearbyArea" type="checkbox" value="93"/>
#            vermont
#            <small>
#             (brl)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_41" name="nearbyArea" type="checkbox" value="10"/>
#            washington, DC
#            <small>
#             (wdc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_48" name="nearbyArea" type="checkbox" value="337"/>
#            watertown, NY
#            <small>
#             (wtn)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_51" name="nearbyArea" type="checkbox" value="329"/>
#            western maryland
#            <small>
#             (wmd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_16" name="nearbyArea" type="checkbox" value="173"/>
#            western massachusetts
#            <small>
#             (wma)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_26" name="nearbyArea" type="checkbox" value="463"/>
#            williamsport, PA
#            <small>
#             (wpt)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_47" name="nearbyArea" type="checkbox" value="711"/>
#            winchester, VA
#            <small>
#             (okv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_25" name="nearbyArea" type="checkbox" value="240"/>
#            worcester / central MA
#            <small>
#             (wor)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled='"disabled"' id="nearbyArea_22" name="nearbyArea" type="checkbox" value="357"/>
#            york, PA
#            <small>
#             (yrk)
#            </small>
#           </label>
#          </li>
#          <li>
#           <span class="nextNearbyZone linklike" data-zone="1">
#            + show
#            <span id="nearbyNumber">
#             65
#            </span>
#            more...
#           </span>
#          </li>
#         </ul>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          miles from zip
#         </span>
#         <input class="flatinput searchInput search_distance" inputmode="numeric" max="200" min="0" name="search_distance" placeholder="miles" size="3" type="number" value=""/>
#         <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value="">
#         </input>
#        </div>
#        <div class="searchgroup minmax ">
#         <span class="searchfieldlabel">
#          price
#         </span>
#         <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value="">
#          <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value="">
#          </input>
#         </input>
#        </div>
#        <div class="searchgroup minmax ">
#         <span class="searchfieldlabel">
#          ft
#          <sup>
#           2
#          </sup>
#         </span>
#         <input class="flatinput min" name="minSqft" placeholder="min" title="whole number, no letters or symbols" type="tel" value="">
#          <input class="flatinput max" name="maxSqft" placeholder="max" title="whole number, no letters or symbols" type="tel" value="">
#          </input>
#         </input>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          availability
#         </span>
#         <select class="autosubmit" name="availabilityMode">
#          <option selected="selected" value="0">
#           all dates
#          </option>
#          <option value="1">
#           within 30 days
#          </option>
#          <option value="2">
#           beyond 30 days
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup">
#         <label class="private_room">
#          <input class="autosubmit" name="private_room" type="checkbox" value="1"/>
#          private room
#         </label>
#         <br/>
#         <label class="private_bath">
#          <input class="autosubmit" name="private_bath" type="checkbox" value="1"/>
#          private bath
#         </label>
#         <br/>
#         <label class="pets_cat">
#          <input class="autosubmit" name="pets_cat" type="checkbox" value="1"/>
#          cats ok
#         </label>
#         <br/>
#         <label class="pets_dog">
#          <input class="autosubmit" name="pets_dog" type="checkbox" value="1"/>
#          dogs ok
#         </label>
#         <br/>
#         <label class="is_furnished">
#          <input class="autosubmit" name="is_furnished" type="checkbox" value="1"/>
#          furnished
#         </label>
#         <br/>
#         <label class="no_smoking">
#          <input class="autosubmit" name="no_smoking" type="checkbox" value="1"/>
#          no smoking
#         </label>
#         <br/>
#         <label class="wheelchaccess">
#          <input class="autosubmit" name="wheelchaccess" type="checkbox" value="1"/>
#          wheelchair access
#         </label>
#         <br/>
#        </div>
#        <div class="searchgroup">
#         <div class="search-attribute hide-list" data-attr="laundry">
#          <div class="title linklike ">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           laundry
#          </div>
#          <ul class="list">
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="laundry_1" name="laundry" type="checkbox" value="1"/>
#             w/d in unit
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="laundry_4" name="laundry" type="checkbox" value="4"/>
#             w/d hookups
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="laundry_2" name="laundry" type="checkbox" value="2"/>
#             laundry in bldg
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="laundry_3" name="laundry" type="checkbox" value="3"/>
#             laundry on site
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="laundry_5" name="laundry" type="checkbox" value="5"/>
#             no laundry on site
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="parking">
#          <div class="title linklike ">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           parking
#          </div>
#          <ul class="list">
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_1" name="parking" type="checkbox" value="1"/>
#             carport
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_2" name="parking" type="checkbox" value="2"/>
#             attached garage
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_3" name="parking" type="checkbox" value="3"/>
#             detached garage
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_4" name="parking" type="checkbox" value="4"/>
#             off-street parking
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_5" name="parking" type="checkbox" value="5"/>
#             street parking
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_6" name="parking" type="checkbox" value="6"/>
#             valet parking
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_7" name="parking" type="checkbox" value="7"/>
#             no parking
#            </label>
#           </li>
#           <li class="selectall js-only ">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="searchgroup resetsearch">
#         <a class="reset linklike" href="/search/roo" title="clear all search parameters">
#          reset
#         </a>
#         <button class="searchlink linklike" type="submit">
#          update search
#         </button>
#        </div>
#       </div>
#      </input>
#     </div>
#     <div class="search-legend">
#      <div class="search-view js-only">
#       <div aria-expanded="false" aria-label="view options" class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar">
#        <ul class="dropdown-list">
#         <li class="dropdown-item mode sel">
#          <button data-selection="list" id="listview" title="show results in a list">
#           <span class="view-list icon">
#           </span>
#           list
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="pic" id="picview" title="show results in a list with thumbnail pictures">
#           <span class="view-thumb icon">
#           </span>
#           thumb
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="grid" id="gridview" title="show results side-by-side with larger pictures">
#           <span class="view-gallery icon">
#           </span>
#           gallery
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="map" id="mapview" title="show results on a map">
#           <span class="view-map icon">
#           </span>
#           map
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="search-sort">
#       <div aria-expanded="false" aria-label="sort options" class="dropdown dropdown-sort dropdown-arrows" data-default-sort="rel" role="toolbar">
#        <ul class="dropdown-list">
#         <li aria-selected="false" class="dropdown-item mode ">
# ...
#           pic
#           <span class="maptag" data-pid="6073706742">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="6047855912" data-repost-of="5956424867">
#        <a class="result-image gallery" data-ids="1:00U0U_8SR56Tm0e5P,1:00D0D_8RluwVqdo5v,1:00p0p_hAC5VW9RAuh,1:00Z0Z_6j0CIQlJ0A7,1:00G0G_e7kCaxUfcO8,1:00p0p_2Rbh1YfRXlO,1:00m0m_7h29QvgcCkO,1:00P0P_46oAQoylJLr,1:00I0I_lU61Ryv8HyS,1:00P0P_hMCHLPvYdad,1:00m0m_iQB0fJvFilg" href="/mnh/roo/6047855912.html">
#         <span class="result-price">
#          $1350
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-04-04 11:01" title="Tue 04 Apr 11:01:37 AM">
#          Apr  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6047855912" href="/mnh/roo/6047855912.html">
#          ROOM IN BRAND NEW 3 BEDROOM PRIME LOCATION
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $1350
#          </span>
#          <span class="result-hood">
#           (East Village)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6047855912">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="6073683927" data-repost-of="5956424867">
#        <a class="result-image gallery" data-ids="1:00U0U_8SR56Tm0e5P,1:00D0D_8RluwVqdo5v,1:00p0p_hAC5VW9RAuh,1:00Z0Z_6j0CIQlJ0A7,1:00G0G_e7kCaxUfcO8,1:00p0p_2Rbh1YfRXlO,1:00m0m_7h29QvgcCkO,1:00P0P_46oAQoylJLr,1:00I0I_lU61Ryv8HyS,1:00P0P_hMCHLPvYdad,1:00m0m_iQB0fJvFilg" href="/mnh/roo/6073683927.html">
#         <span class="result-price">
#          $1500
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-04-04 11:02" title="Tue 04 Apr 11:02:20 AM">
#          Apr  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6073683927" href="/mnh/roo/6073683927.html">
#          ROOM IN BRAND NEW 3 BEDROOM PRIME LOCATION
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $1500
#          </span>
#          <span class="result-hood">
#           (East Village)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6073683927">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="6065803788" data-repost-of="5956424867">
#        <a class="result-image gallery" data-ids="1:00U0U_8SR56Tm0e5P,1:00D0D_8RluwVqdo5v,1:00p0p_hAC5VW9RAuh,1:00Z0Z_6j0CIQlJ0A7,1:00G0G_e7kCaxUfcO8,1:00p0p_2Rbh1YfRXlO,1:00m0m_7h29QvgcCkO,1:00P0P_46oAQoylJLr,1:00I0I_lU61Ryv8HyS,1:00P0P_hMCHLPvYdad,1:00m0m_iQB0fJvFilg" href="/mnh/roo/6065803788.html">
#         <span class="result-price">
#          $1350
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-04-04 10:50" title="Tue 04 Apr 10:50:35 AM">
#          Apr  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6065803788" href="/mnh/roo/6065803788.html">
#          ROOM IN BRAND NEW 3 BEDROOM PRIME LOCATION
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $1350
#          </span>
#          <span class="result-hood">
#           (East Village)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6065803788">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="6073638423" data-repost-of="5961405083">
#        <a class="result-image gallery" data-ids="1:00X0X_16YakLO5Bz5,1:00o0o_1MawTER5dDA,1:00808_hEgiMIXgekA,1:00000_hPQPkLgzWYm,1:01414_MdrxOlg7J2,1:00N0N_lsbbfbUc1qJ,1:00c0c_aThdrARQIWG,1:00S0S_ab5WpEqSBpu,1:00i0i_9xPndB8x8gc" href="/mnh/roo/6073638423.html">
#         <span class="result-price">
#          $1375
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-04-04 10:28" title="Tue 04 Apr 10:28:39 AM">
#          Apr  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6073638423" href="/mnh/roo/6073638423.html">
#          Gay male looking for roommate for pvt furnished Large bedroom+balcony
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $1375
#          </span>
#          <span class="result-hood">
#           (East Village)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6073638423">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         displaying
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/roo?availabilityMode=0&amp;query=east%20village" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/roo?availabilityMode=0&amp;query=east%20village" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          495
#         </span>
#        </span>
#        <a class="button next" href="/search/roo?s=120&amp;availabilityMode=0&amp;query=east%20village" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif">
#       <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif">
#       </img>
#      </img>
#     </div>
#    </form>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorited
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      no longer favorited
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      hidden
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      no longer hidden
#     </span>
#    </div>
#    <footer>
#     <span class="rss">
#      <a class="l" href="https://newyork.craigslist.org/search/roo?availabilityMode=0&amp;format=rss&amp;query=east%20village">
#       RSS
#      </a>
#      <a href="https://www.craigslist.org/about/rss">
#       (?)
#      </a>
#      <br>
#      </br>
#     </span>
#     <ul class="clfooter">
#      <li>
#       ©
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/craigslist_is_hiring">
#        cl jobs
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/terms.of.use.en">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     &lt;
#    </div>
#    <div class="slider-forward arrow">
#     &gt;
#    </div>
#   </template>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=bf53b062904bb5e9fa6a1276bf1fd20d" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     -->
#   </script>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <time class="date timeago"  datetime="{isoPostedDate}">{humanPostedDate}</time>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=73c0568ed67a90bdfefff7bc91f6229c" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/search-concat.min.js?v=6d59a1f985e126f1d7d0291127f1ea22" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
print('Type:', type(cl_soup))
# Out:
# Type: <class 'bs4.BeautifulSoup'>

# %%
# we can access a tag 
print('Title: ', cl_soup.title)
# Out:
# Title:  <title>new york rooms for rent &amp; shares available "east village" - craigslist</title>

# %%
# or only the text content
print('Title: ', cl_soup.title.text) # or
print('Title: ', cl_soup.get_text())
# Out:
# Title:  new york rooms for rent & shares available "east village" - craigslist
# Title:
#
# new york rooms for rent & shares available "east village" - craigslist
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--
# var areaCountry = "US";
# var areaID = "3";
# var areaRegion = "NY";
# var catAbb = "roo";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "list";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 2500;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = null;
# var searchDistance = null;
# var sectionAbb = "hhh";
# var sectionBase = "hhh";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# -->
#
#
#
#
# <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#
#
#
# CL
#
#
#
#
#
#
# new york
#
#
# new york
# albany, NY
# allentown
# altoona
# annapolis
# baltimore
# binghamton
# boston
# cape cod
# catskills
# central NJ
# cumberland val
# delaware
# eastern CT
# eastern shore
# eastern WV
# elmira
# finger lakes
# frederick
# glens falls
# harrisburg
# hartford
# hudson valley
# ithaca
# jersey shore
# lancaster, PA
# long island
# new haven
# north jersey
# northwest CT
# oneonta
# philadelphia
# poconos
# reading
# rhode island
# scranton
# south coast
# south jersey
# southern MD
# state college
# syracuse
# utica
# washington, DC
# western mass
# williamsport
# worcester
# york, PA
#
# >
#
#
#
# all new york
# bronx
# brooklyn
# fairfield
# long island
# manhattan
# new jersey
# queens
# staten island
# westchester
#
# >
#
#
#
# community
# events
# for sale
# gigs
# housing
# jobs
# personals
# resumes
# services
#
# >
#
#
#
# all
# apts broker fee
# apts broker no fee
# apts by owner
# apts registration fee
# apts wanted
# housing swap
# office & commercial
# parking & storage
# real estate - by broker
# real estate - by owner
# real estate wanted
# rooms & shares
# rooms wanted
# sublet/temp wanted
# sublets & temporary
# vacation rentals
# rooms & shares
# >
#
#
#
#
#
#
#
#
#
#
# post
#
#
# account
#
#
#
#
#
# 0 favorites
#
#
#
#
#
#
#
#
#
#
#
# 0
#  hidden
#
#
#
#
#
#
#
#
#
# «»
#
#
#
# press to search craigslist
#
#
# save search
#
#
#
#
#
#         optionsclose
#
#
#
#
#
# rooms for rent & shares available
#
#
#
#
# search titles onlyhas imageposted todaybundle duplicatesinclude nearby areas
#
#
#
#
#                             albany, NY (alb)
#
#
#
#
#
#                             altoona-johnstown (aoo)
#
#
#
#
#
#                             annapolis, MD (anp)
#
#
#
#
#
#                             baltimore, MD (bal)
#
#
#
#
#
#                             belleville, ON (bel)
#
#
#
#
#
#                             binghamton, NY (bgm)
#
#
#
#
#
#                             boston (bos)
#
#
#
#
#
#                             buffalo, NY (buf)
#
#
#
#
#
#                             cape cod / islands (cap)
#
#
#
#
#
#                             catskills (cat)
#
#
#
#
#
#                             central NJ (cnj)
#
#
#
#
#
#                             charlottesville, VA (uva)
#
#
#
#
#
#                             chautauqua, NY (chq)
#
#
#
#
#
#                             cornwall, ON (ycc)
#
#
#
#
#
#                             cumberland valley (cbg)
#
#
#
#
#
#                             delaware (dlw)
#
#
#
#
#
#                             eastern CT (nlo)
#
#
#
#
#
#                             eastern panhandle (ewv)
#
#
#
#
#
#                             eastern shore (esh)
#
#
#
#
#
#                             elmira-corning (elm)
#
#
#
#
#
#                             finger lakes, NY (fgl)
#
#
#
#
#
#                             frederick, MD (fdk)
#
#
#
#
#
#                             fredericksburg, VA (ezf)
#
#
#
#
#
#                             glens falls, NY (gfl)
#
#
#
#
#
#                             hampton roads (nfk)
#
#
#
#
#
#                             harrisburg, PA (hrs)
#
#
#
#
#
#                             harrisonburg, VA (shd)
#
#
#
#
#
#                             hartford, CT (htf)
#
#
#
#
#
#                             hudson valley, NY (hud)
#
#
#
#
#
#                             ithaca, NY (ith)
#
#
#
#
#
#                             jersey shore (jys)
#
#
#
#
#
#                             kingston, ON (kng)
#
#
#
#
#
#                             lancaster, PA (lns)
#
#
#
#
#
#                             lehigh valley (alt)
#
#
#
#
#
#                             long island, NY (isp)
#
#
#
#
#
#                             new hampshire (nhm)
#
#
#
#
#
#                             new haven, CT (hvn)
#
#
#
#
#
#                             north jersey (njy)
#
#
#
#
#
#                             northwest CT (nct)
#
#
#
#
#
#                             oneonta, NY (onh)
#
#
#
#
#
#                             philadelphia (phi)
#
#
#
#
#
#                             plattsburgh-adirondacks (plb)
#
#
#
#
#
#                             poconos (poc)
#
#
#
#
#
#                             potsdam-canton-massena (ptd)
#
#
#
#
#
#                             reading, PA (rea)
#
#
#
#
#
#                             rhode island (prv)
#
#
#
#
#
#                             richmond, VA (ric)
#
#
#
#
#
#                             rochester, NY (rcs)
#
#
#
#
#
#                             scranton / wilkes-barre (avp)
#
#
#
#
#
#                             south coast, MA (sma)
#
#
#
#
#
#                             south jersey (snj)
#
#
#
#
#
#                             southern maryland (smd)
#
#
#
#
#
#                             state college, PA (psu)
#
#
#
#
#
#                             syracuse, NY (syr)
#
#
#
#
#
#                             twin tiers NY/PA (tts)
#
#
#
#
#
#                             utica-rome-oneida (uti)
#
#
#
#
#
#                             vermont (brl)
#
#
#
#
#
#                             washington, DC (wdc)
#
#
#
#
#
#                             watertown, NY (wtn)
#
#
#
#
#
#                             western maryland (wmd)
#
#
#
#
#
#                             western massachusetts (wma)
#
#
#
#
#
#                             williamsport, PA (wpt)
#
#
#
#
#
#                             winchester, VA (okv)
#
#
#
#
#
#                             worcester / central MA (wor)
#
#
#
#
#
#                             york, PA (yrk)
#
#
#
#
#                             + show 65 more...
#
#
#
#
#
# miles from zip
#
#
#
#
# price
#
#
#
#
# ft2
#
#
#
#
# availability
#
# all dates
# within 30 days
# beyond 30 days
#
#
#
#
#     private room
#
#
#
#     private bath
#
#
#
#     cats ok
#
#
#
#     dogs ok
#
#
#
#     furnished
#
#
#
#     no smoking
#
#
#
#     wheelchair access
#
#
#
# ▸▾ laundry
#
#
#
#
#
#                     w/d in unit
#
#
#
#
#
#                     w/d hookups
#
#
#
#
#
#                     laundry in bldg
#
#
#
#
#
#                     laundry on site
#
#
#
#
#
#                     no laundry on site
#
#
#
#
#
#
# ▸▾ parking
#
#
#
#
#
#                     carport
#
#
#
#
#
#                     attached garage
#
#
#
#
#
#                     detached garage
#
#
#
#
#
#                     off-street parking
#
#
#
#
#
#                     street parking
#
#
#
#
#
#                     valet parking
#
#
#
#
#
#                     no parking
#
#
#
# select all
# deselect all
#
#
#
#
#
# reset
# update search
#
#
#
#
#
#
#
#
#
# list
#
#
#
#
#
# thumb
#
#
#
#
#
# gallery
#
#
#
#
#
# map
#
#
#
#
#
#
#
#
#
#
# newest
#
#
# relevant
#
#
# price ↑
#
#
# price ↓
#
#
#
#
#
#
#
#         displaying ... postings
#
#
#
# <<
# <<
# < prev
# < prev
#
#
# 1
#                 -
#                 120
#
#             /
#             495
#
# next >
#  next >
#
#
#
#
#
#
#
#
#
#
#
# see in map view
#
#
#
#
# No mappable items found
#
#
# close fullscreen
# close map
#
#
#
#
#
#
#
# favorite this post
#
# Apr  4
# Room on Central East Village prime location ♥
#
# $500
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1500
#
#
#
# favorite this post
#
# Apr  4
# 1br in 3br apt in East Village - Move in May 1
#
# $1500
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1550
#
#
#
# favorite this post
#
# Apr  4
# 1 BR available in 2BR/1Ba Apt in East Village
#
# $1550
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Apr  3
# 1 Bedroom - East Village Bldg - Doorman
#
# $1595
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $900
#
#
#
# favorite this post
#
# Apr  3
# Cozy room in huge apartment in the heart of the east village
#
# $900
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1500
#
#
#
# favorite this post
#
# Apr  3
# East Village Furnished Room Sublet in a Sunny Apt. Amazing Location.
#
# $1500
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1100
#
#
#
# favorite this post
#
# Apr  3
# Great East Village Location, Facing Garden!
#
# $1100
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1734
#
#
#
# favorite this post
#
# Apr  3
# One bedroom in three bedroom East Village doorman/elevator apartment
#
# $1734
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1750
#
#
#
# favorite this post
#
# Apr  3
# Room In East Village (Modern Building)
#
# $1750
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1700
#
#
#
# favorite this post
#
# Apr  3
# Furnished bedroom in East Village-----May 1st
#
# $1700
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1300
#
#
#
# favorite this post
#
# Apr  3
# Beautiful sunny bedroom in great East Village/Lower East Side apt!
#
# $1300
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1650
#
#
#
# favorite this post
#
# Apr  2
# 1BR Furnished in Furnished 3BR/1BA, Heart of the East Village
#
# $1650
#
#                     72ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1550
#
#
#
# favorite this post
#
# Apr  2
# 1 BR available in 2BR/1Ba Apt in East Village
#
# $1550
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Apr  2
# DOORMAN BLDG Sunny Bright Room in East Village w/ GYM FIOS Patio
#
# $1295
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1300
#
#
#
# favorite this post
#
# Apr  2
# Beautiful sunny bedroom in great East Village/Lower East Side apt!
#
# $1300
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1300
#
#
#
# favorite this post
#
# Apr  3
# Beautiful sunny bedroom in great East Village/Lower East Side apt!
#
# $1300
#  (Lower East Side)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1266
#
#
#
# favorite this post
#
# Apr  2
# 1 Bedroom Available in 3 Bedroom Doorman East Village Apartment
#
# $1266
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Apr  2
# Room in Sunny, Renovated, Gem of 2 BR in East Village by Union Square
#
# $515
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Apr  2
# Fully furnished room in the East Village
#
# $600
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $2500
#
#
#
# favorite this post
#
# Apr  2
# Awesome room in furnished East Village apartment!
#
# $2500
#
#                     1100ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $2200
#
#
#
# favorite this post
#
# Apr  2
# East Village Studio - Lease Takeover
#
# $2200
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1584
#
#
#
# favorite this post
#
# Apr  2
# Room in Spacious 3BR w Rooftop Access Avail Apr 1 - East Village
#
# $1584
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1300
#
#
#
# favorite this post
#
# Apr  2
# Beautiful sunny bedroom in great East Village/Lower East Side apt!
#
# $1300
#  (Lower East Side)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1260
#
#
#
# favorite this post
#
# Apr  1
# Private room sublet in summer - East Village- 1260$
#
# $1260
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
#
# favorite this post
#
# Apr  1
# Room available in Bdr luxury East Village building $1480
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1350
#
#
#
# favorite this post
#
# Apr  2
# Room In Fully Furnished -- Amazing 3 Bedroom Apartment | East Village
#
# $1350
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Apr  1
# Fully furnished room in the East Village
#
# $600
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1650
#
#
#
# favorite this post
#
# Apr  1
# Luxury Doorman Building Master Bedroom In East Village - May 1st
#
# $1650
#
#                     800ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1850
#
#
#
# favorite this post
#
# Apr  1
# ** Free laundry! - MOVE IN to an East Village, PreWar Apt, etc -- PICS
#
# $1850
#
#                     950ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Mar 31
# Sunny Room in East Village DRMN BLDG w/ GYM & Patio,
#
# $1295
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1850
#
#
#
# favorite this post
#
# Mar 31
# ** Free laundry! - MOVE IN to an East Village, PreWar Apt, etc -- PICS
#
# $1850
#
#                     950ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1425
#
#
#
# favorite this post
#
# Mar 31
# Hidden Gem In The Heart Of East Village!!! Won't Last!!!!
#
# $1425
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1100
#
#
#
# favorite this post
#
# Mar 31
# **ASAP Large Bedroom East Village Perfect Location Move in ASAP
#
# $1100
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1650
#
#
#
# favorite this post
#
# Mar 30
# INCREDIBLY LARGE ROOM AVAILABLE IN THE EAST VILLAGE: GREAT PRICE!
#
# $1650
#
#                     150ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1850
#
#
#
# favorite this post
#
# Mar 30
# ** Free laundry! - MOVE IN to an East Village, PreWar Apt, etc -- PICS
#
# $1850
#
#                     950ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1325
#
#
#
# favorite this post
#
# Mar 30
# No Fee!Queen Sized Rm in East Village For $1325 a month,call me today!
#
# $1325
#
#                     800ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1800
#
#
#
# favorite this post
#
# Mar 29
# Furnished Room in East Village Doorman Building
#
# $1800
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1400
#
#
#
# favorite this post
#
# Mar 30
# Queen room in 2BR, large living room, LES / East Village. Avail 4/15
#
# $1400
#  (Lower East Side)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $400
#
#
#
# favorite this post
#
# Mar 30
# room in the east village
#
# $400
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1775
#
#
#
# favorite this post
#
# Mar 29
# East Village Goregous Share Downtown Living Prime Location
#
# $1775
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1415
#
#
#
# favorite this post
#
# Mar 29
# EAST VILLAGE- Bedroom in Amazing 3bdrm w private ROOF DECK
#
# $1415
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Mar 29
# GREAT East Village Sublet in True 2 Bedroom Apartment
#
# $1850
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1850
#
#
#
# favorite this post
#
# Mar 29
# ** Free laundry! - MOVE IN to an East Village, PreWar Apt, etc -- PICS
#
# $1850
#
#                     950ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1425
#
#
#
# favorite this post
#
# Mar 29
# Great Room In Great 3BR Apartment In The Heart Of East Village!!!
#
# $1425
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
#
# favorite this post
#
# Mar 28
# 1,450 May 1st, East Village, elevator/doorman, backyard, and balcony
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1630
#
#
#
# favorite this post
#
# Mar 28
# 1 BR in 3 BR East Village - $1630 - Avail 4/1
#
# $1630
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1575
#
#
#
# favorite this post
#
# Mar 28
# Room available on St Marks Place in East Village!
#
# $1575
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1200
#
#
#
# favorite this post
#
# Mar 28
# 1 bedroom in shared East Village Apt Available April 1st
#
# $1200
#
#                     80ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1850
#
#
#
# favorite this post
#
# Mar 28
# ** Free laundry! - MOVE IN to an East Village, PreWar Apt, etc -- PICS
#
# $1850
#
#                     950ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1740
#
#
#
# favorite this post
#
# Apr  2
# Large East Village Bedroom (Utilities Included)
#
# $1740
#
#                     935ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1730
#
#
#
# favorite this post
#
# Apr  1
# Sunny East Village Bedroom (Utilities Included)
#
# $1730
#
#                     935ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1600
#
#
#
# favorite this post
#
# Mar 31
# SEMI FURNISHED 2 ROOM EAST VILLAGE PAD AVA NOW
#
# $1600
#
#                     800ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Mar 31
# Queen Size Sunny Room in East Village DRMN BLDG w/ GYM & Patio,
#
# $1395
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1511
#
#
#
# favorite this post
#
# Mar 29
# Bright and sunny bedroom in corner apt. in East Village JUNE 1 MOVE IN
#
# $1511
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Apr  4
# masterbedroom   east village share
#
# $1100
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1900
#
#
#
# favorite this post
#
# Apr  3
# Large room in East Village/Bowery 3 bedroom share (May 1)
#
# $1900
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $115
#
#
#
# favorite this post
#
# Apr  3
# Fantastic East Village Studio, Perfect Location, Tons Of Light, Large
#
# $115
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1300
#
#
#
# favorite this post
#
# Apr  3
# Bedroom Available in Massive East Village Apartment
#
# $1300
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1700
#
#
#
# favorite this post
#
# Apr  3
# East Village - Sublet
#
# $1700
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Apr  3
# masterbedroom   east village share
#
# $1100
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1600
#
#
#
# favorite this post
#
# Apr  2
# Available Now - 1 BR for Rent in 3 BR Apt in LES/East Village
#
# $1600
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1650
#
#
#
# favorite this post
#
# Apr  2
# LARGE ROOM AVAILABLE IN THE EAST VILLAGE - CHECK IT OUT!
#
# $1650
#
#                     150ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Apr  2
# Fully Furnished 150sq/ft Room in East Village
#
# $540
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Apr  4
# roommate wanted east village
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1850
#
#
#
# favorite this post
#
# Apr  2
# Room Available in Massive East Village Apartment
#
# $1850
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Apr  3
# roommate wanted east village
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Apr  2
# roommate wanted east village
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1600
#
#
#
# favorite this post
#
# Apr  1
# Available Now - 1 BR for Rent in 3 BR Apt in LES/East Village
#
# $1600
#  (Lower East Side)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Apr  2
# roommate wanted east village open house today only
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1900
#
#
#
# favorite this post
#
# Mar 31
# $1,900, large room in East Village/Bowery 3 bedroom share (May 1)
#
# $1900
#
#                     120ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Apr  1
# roommate wanted east village
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1300
#
#
#
# favorite this post
#
# Apr  1
# East Village Room for Rent
#
# $1300
#  (Downtown)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Apr  1
# roommate wanted east village
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Mar 30
# masterbedroom   east village share
#
# $1100
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1000
#
#
#
# favorite this post
#
# Mar 30
# 132ft - $1000 - East Village A Private Room in Shared Loft
#
# $1000
#
#                     132ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Mar 31
# roommate wanted east village
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Mar 31
# Furnished room  east village
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1300
#
#
#
# favorite this post
#
# Mar 30
# East Village Room for Rent
#
# $1300
#  (Downtown)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Mar 29
# masterbedroom   east village share
#
# $1100
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Mar 30
# roommate wanted east village
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1300
#
#
#
# favorite this post
#
# Mar 28
# East Village Room for Rent
#
# $1300
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1650
#
#
#
# favorite this post
#
# Mar 28
# STUNNING LARGE ROOM AVAILABLE IN THE EAST VILLAGE - CHECK IT OUT!
#
# $1650
#
#                     150ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1510
#
#
#
# favorite this post
#
# Mar 28
# Room Available - 4/1 (East Village)
#
# $1510
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1300
#
#
#
# favorite this post
#
# Mar 29
# East Village Room for Rent
#
# $1300
#  (Downtown)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Mar 29
# furnished room  east village
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Mar 28
# masterbedroom   east village share
#
# $1100
#  (East Village)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1250
#
#
#
# favorite this post
#
# Mar 29
# roommate wanted east village
#
# $1250
#
#                     400ft2 -
#
#  (Union Square)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $2350
#
#
#
# favorite this post
#
# Apr  3
# One bedroom in 2000 sq. ft. E. Village Loft
#
# $2350
#  (E. Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1650
#
#
#
# favorite this post
#
# Apr  2
# Room avail- cute 3br E.Village apt w/elevator, terrace, laundry on flr
#
# $1650
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1600
#
#
#
# favorite this post
#
# Apr  3
# One Room in a Fully Furnished - Huge 5 Bedroom, 2 Bathroom Loft | East
#
# $1600
#
#                     1500ft2 -
#
#  (Greenwich Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1400
#
#
#
# favorite this post
#
# Apr  2
# Daily Open House in the E Village Find Your Room And Roommates Today
#
# $1400
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1150
#
#
#
# favorite this post
#
# Apr  3
# East 92 Street- Renovated three bedrooms/ one bath at UES!
#
# $1150
#  (Upper East Side)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1900
#
#
#
# favorite this post
#
# Apr  3
# 1br - Peter Cooper Village
#
# $1900
#
#                     1200ft2 -
#
#  (Gramercy)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Apr  2
# Nice furnished room for rent trendy lower east side close to all
#
# $650
#
#                     60ft2 -
#
#  (Lower East Side)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1450
#
#
#
# favorite this post
#
# Apr  3
# Cozy Furnished Room in Best Area in Soho/Village duplex w yard, NYU
#
# $1450
#
#                     1500ft2 -
#
#  (SoHo)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1750
#
#
#
# favorite this post
#
# Apr  3
# Large Furnished Room in Best Area in Soho/Village duplex w yard, NYU
#
# $1750
#
#                     1500ft2 -
#
#  (SoHo)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1400
#
#
#
# favorite this post
#
# Apr  1
# Daily Open House in the E Village Find Your Room And Roommates Today
#
# $1400
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1750
#
#
#
# favorite this post
#
# Apr  2
# Large Furnished Room in Best Area in Soho/Village duplex w yard, NYU
#
# $1750
#
#                     1500ft2 -
#
#  (SoHo)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1450
#
#
#
# favorite this post
#
# Mar 31
# Room Available In Greenwich Village - Thompson/Bleecker
#
# $1450
#  (Greenwich Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $105
#
#
#
# favorite this post
#
# Mar 30
# Exceptional East Vi Studio, Huge Space, Tons Of Light, Great Location
#
# $105
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $105
#
#
#
# favorite this post
#
# Mar 30
# Stunning Brand New East Vil, Queen Bed, Elevator, Great Location
#
# $105
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1833
#
#
#
# favorite this post
#
# Mar 28
# East 9th Street Apartment - TRUE Bedroom available - 1 MONTH FREE
#
# $1833
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Mar 28
# SMALL ROOM: jackson heights/woodside/astoria/midtown east/sunnyside
#
# $790
#  (Jackson Heights)
#
# map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $900
#
#
#
# favorite this post
#
# Apr  3
# Room For Rent In Greenwich Village
#
# $900
#  (Greenwich Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1450
#
#
#
# favorite this post
#
# Apr  1
# PRIVATE ROOM IN LOWER EAST SIDE MOVE IN FROM APRIL 15!
#
# $1450
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $125
#
#
#
# favorite this post
#
# Apr  4
# Spacious East Vil Studio, New, Ready To Go, Queen Bed, Killer Location
#
# $125
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $125
#
#
#
# favorite this post
#
# Apr  4
# Exceptional East Vi Studio, Huge Space, Tons Of Light, Great Location
#
# $125
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1400
#
#
#
# favorite this post
#
# Apr  3
# Daily Open House in the E Village Find Your Room And Roommates Today
#
# $1400
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1400
#
#
#
# favorite this post
#
# Apr  2
# Daily Open House in the E Village Find Your Room And Roommates Today
#
# $1400
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1400
#
#
#
# favorite this post
#
# Apr  1
# Daily Open House in the E Village Find Your Room And Roommates Today
#
# $1400
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $105
#
#
#
# favorite this post
#
# Mar 30
# Exceptional East Vi Studio, Huge Space, Tons Of Light, Great Location
#
# $105
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1400
#
#
#
# favorite this post
#
# Mar 29
# Daily Open House in the E Village Find Your Room And Roommates Today
#
# $1400
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1450
#
#
#
# favorite this post
#
# Mar 28
# Large Room for Rent in the Village
#
# $1450
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1400
#
#
#
# favorite this post
#
# Apr  4
# Seeking A Room For 12 Months- It's Only Right That You 📞Asap!
#
# $1400
#
#                     1000ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1650
#
#
#
# favorite this post
#
# Apr  4
# AMAZING, LARGE ROOM IN STUYVESANT TOWN - PRICE REDUCED, AVAILABLE NOW!
#
# $1650
#
#                     150ft2 -
#
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1500
#
#
#
# favorite this post
#
# Apr  4
# short term rental - Room available in HUGE 5br apt- No fee
#
# $1500
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1350
#
#
#
# favorite this post
#
# Apr  4
# ROOM IN BRAND NEW 3 BEDROOM PRIME LOCATION
#
# $1350
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1500
#
#
#
# favorite this post
#
# Apr  4
# ROOM IN BRAND NEW 3 BEDROOM PRIME LOCATION
#
# $1500
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1350
#
#
#
# favorite this post
#
# Apr  4
# ROOM IN BRAND NEW 3 BEDROOM PRIME LOCATION
#
# $1350
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
# $1375
#
#
#
# favorite this post
#
# Apr  4
# Gay male looking for roommate for pvt furnished Large bedroom+balcony
#
# $1375
#  (East Village)
#
#                     pic
#                     map
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# ^ back to top
#
#
# ^ back to top
#
#
#
#
#         displaying ... postings
#
#
#
# <<
# <<
# < prev
# < prev
#
#
# 1
#                 -
#                 120
#
#             /
#             495
#
# next >
#  next >
#
#
#
#
#
#
#
#
#
#
#
#
#
#         favorited
#
#
#
#         no longer favorited
#
#
#
#         hidden
#
#
#
#         no longer hidden
#
#
#
#
# RSS
# (?)
#
#
# ©  craigslistCL
# help
# safety
# privacy
# feedback
# cl jobs
# terms
# about
# mobile
# desktop
#
#
#
#
# <>
#
#
# <!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     -->
#
#     <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#
#
#     <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <time class="date timeago"  datetime="{isoPostedDate}">{humanPostedDate}</time>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#
#
#     <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>

# %% [markdown]
# We can find all tags of certain type with the `find_all` method. This returns a list.

# %%
cl_soup.find_all?

# %% [markdown]
# To get the first paragraph in the html write

# %%
cl_soup.find_all('p')
# Out:
# [<p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 13:54" title="Tue 04 Apr 01:54:15 PM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6058998250" href="/mnh/roo/6058998250.html">Room on Central East Village prime location ♥</a>
#  <span class="result-meta">
#  <span class="result-price">$500</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#  <span class="maptag" data-pid="6058998250">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 13:42" title="Tue 04 Apr 01:42:56 PM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6073957496" href="/mnh/roo/6073957496.html">1br in 3br apt in East Village - Move in May 1</a>
#  <span class="result-meta">
#  <span class="result-price">$1500</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6073957496">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 10:34" title="Tue 04 Apr 10:34:18 AM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6073647116" href="/mnh/roo/6073647116.html">1 BR available in 2BR/1Ba Apt in East Village</a>
#  <span class="result-meta">
#  <span class="result-price">$1550</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6073647116">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-03 21:29" title="Mon 03 Apr 09:29:41 PM">Apr  3</time>
#  <a class="result-title hdrlnk" data-id="6065914838" href="/mnh/roo/6065914838.html">1 Bedroom - East Village Bldg - Doorman</a>
#  <span class="result-meta">
#  <span class="result-price">$1595</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#  <span class="maptag" data-pid="6065914838">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-03 16:13" title="Mon 03 Apr 04:13:14 PM">Apr  3</time>
#  <a class="result-title hdrlnk" data-id="6072717871" href="/mnh/roo/6072717871.html">Cozy room in huge apartment in the heart of the east village</a>
#  <span class="result-meta">
#  <span class="result-price">$900</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6072717871">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-03 15:44" title="Mon 03 Apr 03:44:52 PM">Apr  3</time>
#  <a class="result-title hdrlnk" data-id="6072672057" href="/mnh/roo/6072672057.html">East Village Furnished Room Sublet in a Sunny Apt. Amazing Location.</a>
#  <span class="result-meta">
#  <span class="result-price">$1500</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6072672057">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-03 15:17" title="Mon 03 Apr 03:17:02 PM">Apr  3</time>
#  <a class="result-title hdrlnk" data-id="6050790054" href="/mnh/roo/6050790054.html">Great East Village Location, Facing Garden!</a>
#  <span class="result-meta">
#  <span class="result-price">$1100</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6050790054">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-03 14:14" title="Mon 03 Apr 02:14:19 PM">Apr  3</time>
#  <a class="result-title hdrlnk" data-id="6072517459" href="/mnh/roo/6072517459.html">One bedroom in three bedroom East Village doorman/elevator apartment</a>
#  <span class="result-meta">
#  <span class="result-price">$1734</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6072517459">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-03 13:32" title="Mon 03 Apr 01:32:38 PM">Apr  3</time>
#  <a class="result-title hdrlnk" data-id="6072443769" href="/mnh/roo/6072443769.html">Room In East Village (Modern Building)</a>
#  <span class="result-meta">
#  <span class="result-price">$1750</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6072443769">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-03 10:58" title="Mon 03 Apr 10:58:42 AM">Apr  3</time>
#  <a class="result-title hdrlnk" data-id="6068586529" href="/mnh/roo/6068586529.html">Furnished bedroom in East Village-----May 1st</a>
#  <span class="result-meta">
#  <span class="result-price">$1700</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6068586529">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-03 09:06" title="Mon 03 Apr 09:06:39 AM">Apr  3</time>
#  <a class="result-title hdrlnk" data-id="6066076874" href="/mnh/roo/6066076874.html">Beautiful sunny bedroom in great East Village/Lower East Side apt!</a>
#  <span class="result-meta">
#  <span class="result-price">$1300</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6066076874">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 21:40" title="Sun 02 Apr 09:40:51 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6071631455" href="/mnh/roo/6071631455.html">1BR Furnished in Furnished 3BR/1BA, Heart of the East Village</a>
#  <span class="result-meta">
#  <span class="result-price">$1650</span>
#  <span class="housing">
#                      72ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6071631455">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 21:29" title="Sun 02 Apr 09:29:23 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6071624855" href="/mnh/roo/6071624855.html">1 BR available in 2BR/1Ba Apt in East Village</a>
#  <span class="result-meta">
#  <span class="result-price">$1550</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6071624855">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 21:19" title="Sun 02 Apr 09:19:49 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6057762844" href="/mnh/roo/6057762844.html">DOORMAN BLDG Sunny Bright Room in East Village w/ GYM FIOS Patio</a>
#  <span class="result-meta">
#  <span class="result-price">$1295</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#  <span class="maptag" data-pid="6057762844">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 21:15" title="Sun 02 Apr 09:15:33 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6068622561" href="/mnh/roo/6068622561.html">Beautiful sunny bedroom in great East Village/Lower East Side apt!</a>
#  <span class="result-meta">
#  <span class="result-price">$1300</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6068622561">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-03 09:06" title="Mon 03 Apr 09:06:40 AM">Apr  3</time>
#  <a class="result-title hdrlnk" data-id="6066076833" href="/mnh/roo/6066076833.html">Beautiful sunny bedroom in great East Village/Lower East Side apt!</a>
#  <span class="result-meta">
#  <span class="result-price">$1300</span>
#  <span class="result-hood"> (Lower East Side)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6066076833">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 19:02" title="Sun 02 Apr 07:02:02 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6071460210" href="/mnh/roo/6071460210.html">1 Bedroom Available in 3 Bedroom Doorman East Village Apartment</a>
#  <span class="result-meta">
#  <span class="result-price">$1266</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6071460210">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 17:29" title="Sun 02 Apr 05:29:15 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6058136417" href="/mnh/roo/6058136417.html">Room in Sunny, Renovated, Gem of 2 BR in East Village by Union Square</a>
#  <span class="result-meta">
#  <span class="result-price">$515</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#  <span class="maptag" data-pid="6058136417">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 17:02" title="Sun 02 Apr 05:02:36 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6035517686" href="/mnh/roo/6035517686.html">Fully furnished room in the East Village</a>
#  <span class="result-meta">
#  <span class="result-price">$600</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#  <span class="maptag" data-pid="6035517686">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 16:47" title="Sun 02 Apr 04:47:15 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6071285816" href="/mnh/roo/6071285816.html">Awesome room in furnished East Village apartment!</a>
#  <span class="result-meta">
#  <span class="result-price">$2500</span>
#  <span class="housing">
#                      1100ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6071285816">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 12:36" title="Sun 02 Apr 12:36:47 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6070917702" href="/mnh/roo/6070917702.html">East Village Studio - Lease Takeover</a>
#  <span class="result-meta">
#  <span class="result-price">$2200</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6070917702">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 11:45" title="Sun 02 Apr 11:45:09 AM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6062156244" href="/mnh/roo/6062156244.html">Room in Spacious 3BR w Rooftop Access Avail Apr 1 - East Village</a>
#  <span class="result-meta">
#  <span class="result-price">$1584</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6062156244">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 21:15" title="Sun 02 Apr 09:15:18 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6068623509" href="/mnh/roo/6068623509.html">Beautiful sunny bedroom in great East Village/Lower East Side apt!</a>
#  <span class="result-meta">
#  <span class="result-price">$1300</span>
#  <span class="result-hood"> (Lower East Side)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6068623509">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-01 21:15" title="Sat 01 Apr 09:15:45 PM">Apr  1</time>
#  <a class="result-title hdrlnk" data-id="6070281728" href="/mnh/roo/6070281728.html">Private room sublet in summer - East Village- 1260$</a>
#  <span class="result-meta">
#  <span class="result-price">$1260</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6070281728">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-01 19:30" title="Sat 01 Apr 07:30:41 PM">Apr  1</time>
#  <a class="result-title hdrlnk" data-id="6070157224" href="/mnh/roo/6070157224.html">Room available in Bdr luxury East Village building $1480</a>
#  <span class="result-meta">
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6070157224">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 19:56" title="Sun 02 Apr 07:56:47 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6071518181" href="/mnh/roo/6071518181.html">Room In Fully Furnished -- Amazing 3 Bedroom Apartment | East Village</a>
#  <span class="result-meta">
#  <span class="result-price">$1350</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6071518181">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-01 16:25" title="Sat 01 Apr 04:25:20 PM">Apr  1</time>
#  <a class="result-title hdrlnk" data-id="6061223501" href="/mnh/roo/6061223501.html">Fully furnished room in the East Village</a>
#  <span class="result-meta">
#  <span class="result-price">$600</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#  <span class="maptag" data-pid="6061223501">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-01 14:17" title="Sat 01 Apr 02:17:13 PM">Apr  1</time>
#  <a class="result-title hdrlnk" data-id="6069722524" href="/mnh/roo/6069722524.html">Luxury Doorman Building Master Bedroom In East Village - May 1st</a>
#  <span class="result-meta">
#  <span class="result-price">$1650</span>
#  <span class="housing">
#                      800ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6069722524">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-01 12:22" title="Sat 01 Apr 12:22:36 PM">Apr  1</time>
#  <a class="result-title hdrlnk" data-id="6069523671" href="/mnh/roo/6069523671.html">** Free laundry! - MOVE IN to an East Village, PreWar Apt, etc -- PICS</a>
#  <span class="result-meta">
#  <span class="result-price">$1850</span>
#  <span class="housing">
#                      950ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6069523671">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-31 23:12" title="Fri 31 Mar 11:12:17 PM">Mar 31</time>
#  <a class="result-title hdrlnk" data-id="6059907505" href="/mnh/roo/6059907505.html">Sunny Room in East Village DRMN BLDG w/ GYM &amp; Patio,</a>
#  <span class="result-meta">
#  <span class="result-price">$1295</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#  <span class="maptag" data-pid="6059907505">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-31 12:14" title="Fri 31 Mar 12:14:04 PM">Mar 31</time>
#  <a class="result-title hdrlnk" data-id="6068083084" href="/mnh/roo/6068083084.html">** Free laundry! - MOVE IN to an East Village, PreWar Apt, etc -- PICS</a>
#  <span class="result-meta">
#  <span class="result-price">$1850</span>
#  <span class="housing">
#                      950ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6068083084">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-31 08:57" title="Fri 31 Mar 08:57:11 AM">Mar 31</time>
#  <a class="result-title hdrlnk" data-id="6067803819" href="/mnh/roo/6067803819.html">Hidden Gem In The Heart Of East Village!!! Won't Last!!!!</a>
#  <span class="result-meta">
#  <span class="result-price">$1425</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6067803819">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-31 00:06" title="Fri 31 Mar 12:06:42 AM">Mar 31</time>
#  <a class="result-title hdrlnk" data-id="6067559210" href="/mnh/roo/6067559210.html">**ASAP Large Bedroom East Village Perfect Location Move in ASAP</a>
#  <span class="result-meta">
#  <span class="result-price">$1100</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6067559210">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-30 17:23" title="Thu 30 Mar 05:23:30 PM">Mar 30</time>
#  <a class="result-title hdrlnk" data-id="6067133029" href="/mnh/roo/6067133029.html">INCREDIBLY LARGE ROOM AVAILABLE IN THE EAST VILLAGE: GREAT PRICE!</a>
#  <span class="result-meta">
#  <span class="result-price">$1650</span>
#  <span class="housing">
#                      150ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6067133029">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-30 11:28" title="Thu 30 Mar 11:28:04 AM">Mar 30</time>
#  <a class="result-title hdrlnk" data-id="6066575750" href="/mnh/roo/6066575750.html">** Free laundry! - MOVE IN to an East Village, PreWar Apt, etc -- PICS</a>
#  <span class="result-meta">
#  <span class="result-price">$1850</span>
#  <span class="housing">
#                      950ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6066575750">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-30 11:14" title="Thu 30 Mar 11:14:13 AM">Mar 30</time>
#  <a class="result-title hdrlnk" data-id="6063126853" href="/mnh/roo/6063126853.html">No Fee!Queen Sized Rm in East Village For $1325 a month,call me today!</a>
#  <span class="result-meta">
#  <span class="result-price">$1325</span>
#  <span class="housing">
#                      800ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6063126853">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-29 23:33" title="Wed 29 Mar 11:33:27 PM">Mar 29</time>
#  <a class="result-title hdrlnk" data-id="6057888332" href="/mnh/roo/6057888332.html">Furnished Room in East Village Doorman Building</a>
#  <span class="result-meta">
#  <span class="result-price">$1800</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6057888332">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-30 10:02" title="Thu 30 Mar 10:02:47 AM">Mar 30</time>
#  <a class="result-title hdrlnk" data-id="6055449881" href="/mnh/roo/6055449881.html">Queen room in 2BR, large living room, LES / East Village. Avail 4/15</a>
#  <span class="result-meta">
#  <span class="result-price">$1400</span>
#  <span class="result-hood"> (Lower East Side)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6055449881">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-30 18:06" title="Thu 30 Mar 06:06:07 PM">Mar 30</time>
#  <a class="result-title hdrlnk" data-id="6067216268" href="/mnh/roo/6067216268.html">room in the east village</a>
#  <span class="result-meta">
#  <span class="result-price">$400</span>
#  <span class="result-hood"> (Union Square)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6067216268">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-29 16:32" title="Wed 29 Mar 04:32:33 PM">Mar 29</time>
#  <a class="result-title hdrlnk" data-id="6065616266" href="/mnh/roo/6065616266.html">East Village Goregous Share Downtown Living Prime Location</a>
#  <span class="result-meta">
#  <span class="result-price">$1775</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6065616266">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-29 15:11" title="Wed 29 Mar 03:11:36 PM">Mar 29</time>
#  <a class="result-title hdrlnk" data-id="6065488224" href="/mnh/roo/6065488224.html">EAST VILLAGE- Bedroom in Amazing 3bdrm w private ROOF DECK</a>
#  <span class="result-meta">
#  <span class="result-price">$1415</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6065488224">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-29 12:06" title="Wed 29 Mar 12:06:04 PM">Mar 29</time>
#  <a class="result-title hdrlnk" data-id="6052305335" href="/mnh/roo/6052305335.html">GREAT East Village Sublet in True 2 Bedroom Apartment</a>
#  <span class="result-meta">
#  <span class="result-price">$1850</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#  <span class="maptag" data-pid="6052305335">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-29 09:33" title="Wed 29 Mar 09:33:06 AM">Mar 29</time>
#  <a class="result-title hdrlnk" data-id="6064922141" href="/mnh/roo/6064922141.html">** Free laundry! - MOVE IN to an East Village, PreWar Apt, etc -- PICS</a>
#  <span class="result-meta">
#  <span class="result-price">$1850</span>
#  <span class="housing">
#                      950ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6064922141">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-29 07:37" title="Wed 29 Mar 07:37:59 AM">Mar 29</time>
#  <a class="result-title hdrlnk" data-id="6064815616" href="/mnh/roo/6064815616.html">Great Room In Great 3BR Apartment In The Heart Of East Village!!!</a>
#  <span class="result-meta">
#  <span class="result-price">$1425</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6064815616">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-28 22:47" title="Tue 28 Mar 10:47:00 PM">Mar 28</time>
#  <a class="result-title hdrlnk" data-id="6064579443" href="/mnh/roo/6064579443.html">1,450 May 1st, East Village, elevator/doorman, backyard, and balcony</a>
#  <span class="result-meta">
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6064579443">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-28 17:40" title="Tue 28 Mar 05:40:29 PM">Mar 28</time>
#  <a class="result-title hdrlnk" data-id="6045333232" href="/mnh/roo/6045333232.html">1 BR in 3 BR East Village - $1630 - Avail 4/1</a>
#  <span class="result-meta">
#  <span class="result-price">$1630</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6045333232">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-28 15:31" title="Tue 28 Mar 03:31:48 PM">Mar 28</time>
#  <a class="result-title hdrlnk" data-id="6064074552" href="/mnh/roo/6064074552.html">Room available on St Marks Place in East Village!</a>
#  <span class="result-meta">
#  <span class="result-price">$1575</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6064074552">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
# ...
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6069973128">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 13:09" title="Tue 04 Apr 01:09:11 PM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6039770117" href="/mnh/roo/6039770117.html">Spacious East Vil Studio, New, Ready To Go, Queen Bed, Killer Location</a>
#  <span class="result-meta">
#  <span class="result-price">$125</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6039770117">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 13:01" title="Tue 04 Apr 01:01:45 PM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6039760728" href="/mnh/roo/6039760728.html">Exceptional East Vi Studio, Huge Space, Tons Of Light, Great Location</a>
#  <span class="result-meta">
#  <span class="result-price">$125</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6039760728">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-03 18:35" title="Mon 03 Apr 06:35:42 PM">Apr  3</time>
#  <a class="result-title hdrlnk" data-id="6067740111" href="/mnh/roo/6067740111.html">Daily Open House in the E Village Find Your Room And Roommates Today</a>
#  <span class="result-meta">
#  <span class="result-price">$1400</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6067740111">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-02 21:43" title="Sun 02 Apr 09:43:15 PM">Apr  2</time>
#  <a class="result-title hdrlnk" data-id="6071638762" href="/mnh/roo/6071638762.html">Daily Open House in the E Village Find Your Room And Roommates Today</a>
#  <span class="result-meta">
#  <span class="result-price">$1400</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6071638762">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-01 07:18" title="Sat 01 Apr 07:18:01 AM">Apr  1</time>
#  <a class="result-title hdrlnk" data-id="6069163764" href="/mnh/roo/6069163764.html">Daily Open House in the E Village Find Your Room And Roommates Today</a>
#  <span class="result-meta">
#  <span class="result-price">$1400</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6069163764">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-30 13:21" title="Thu 30 Mar 01:21:34 PM">Mar 30</time>
#  <a class="result-title hdrlnk" data-id="6042501006" href="/mnh/roo/6042501006.html">Exceptional East Vi Studio, Huge Space, Tons Of Light, Great Location</a>
#  <span class="result-meta">
#  <span class="result-price">$105</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6042501006">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-29 17:34" title="Wed 29 Mar 05:34:32 PM">Mar 29</time>
#  <a class="result-title hdrlnk" data-id="6062272300" href="/mnh/roo/6062272300.html">Daily Open House in the E Village Find Your Room And Roommates Today</a>
#  <span class="result-meta">
#  <span class="result-price">$1400</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6062272300">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-03-28 23:15" title="Tue 28 Mar 11:15:45 PM">Mar 28</time>
#  <a class="result-title hdrlnk" data-id="6064573039" href="/mnh/roo/6064573039.html">Large Room for Rent in the Village</a>
#  <span class="result-meta">
#  <span class="result-price">$1450</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6064573039">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 13:22" title="Tue 04 Apr 01:22:47 PM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6046964496" href="/mnh/roo/6046964496.html">Seeking A Room For 12 Months- It's Only Right That You 📞Asap!</a>
#  <span class="result-meta">
#  <span class="result-price">$1400</span>
#  <span class="housing">
#                      1000ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6046964496">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 11:49" title="Tue 04 Apr 11:49:47 AM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6073764677" href="/mnh/roo/6073764677.html">AMAZING, LARGE ROOM IN STUYVESANT TOWN - PRICE REDUCED, AVAILABLE NOW!</a>
#  <span class="result-meta">
#  <span class="result-price">$1650</span>
#  <span class="housing">
#                      150ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6073764677">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 11:16" title="Tue 04 Apr 11:16:02 AM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6073706742" href="/mnh/roo/6073706742.html">short term rental - Room available in HUGE 5br apt- No fee</a>
#  <span class="result-meta">
#  <span class="result-price">$1500</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6073706742">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 11:01" title="Tue 04 Apr 11:01:37 AM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6047855912" href="/mnh/roo/6047855912.html">ROOM IN BRAND NEW 3 BEDROOM PRIME LOCATION</a>
#  <span class="result-meta">
#  <span class="result-price">$1350</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6047855912">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 11:02" title="Tue 04 Apr 11:02:20 AM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6073683927" href="/mnh/roo/6073683927.html">ROOM IN BRAND NEW 3 BEDROOM PRIME LOCATION</a>
#  <span class="result-meta">
#  <span class="result-price">$1500</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6073683927">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 10:50" title="Tue 04 Apr 10:50:35 AM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6065803788" href="/mnh/roo/6065803788.html">ROOM IN BRAND NEW 3 BEDROOM PRIME LOCATION</a>
#  <span class="result-meta">
#  <span class="result-price">$1350</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6065803788">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>, <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2017-04-04 10:28" title="Tue 04 Apr 10:28:39 AM">Apr  4</time>
#  <a class="result-title hdrlnk" data-id="6073638423" href="/mnh/roo/6073638423.html">Gay male looking for roommate for pvt furnished Large bedroom+balcony</a>
#  <span class="result-meta">
#  <span class="result-price">$1375</span>
#  <span class="result-hood"> (East Village)</span>
#  <span class="result-tags">
#                      pic
#                      <span class="maptag" data-pid="6073638423">map</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </p>]

# %% [markdown]
# This is a lot of information and we want to extract some part of it. Use the `text` or `get_text()` method to get the text content.

# %% [markdown]
# This is still messy. We will need a smarter search.

# %% [markdown]
# We can also access the `children` of a certain tag. For example here are the children of the first paragraph tag.

# %%
list(cl_soup.find_all('p')[0].children)

# %% [markdown]
# Look for tags based on their class. This is extremely useful for efficiently locating information.

# %%
cl_soup.find_all('span', class_='result-price')[0].get_text()

# %%
prices = cl_soup.find_all('span', class_='result-price')

# %%
price_data = [price.get_text() for price in prices]

# %%
price_data[:10]

# %%
len(price_data)

# %% [markdown]
# We are getting more cells than we want -- there were only 120 listings on the page. Check the ads with "Inspect Element".

# %%
cl_soup.find_all('li', class_='result-row')[0]

# %%
ads = cl_soup.find_all('li', class_='result-row')

# %% [markdown]
# What's going wrong? Some ads don't have a price listed, so we can't retrieve it.

# %%
import bs4

data = [[ad.find('a', class_='result-title hdrlnk').get_text(), 
         ad.find('a', class_='result-title hdrlnk')['data-id'], 
         ad.find('span', class_='result-price').get_text()] for ad in ads 
        if ...]

# %% [markdown]
# We only have x listing because (120-x) listings did not have a price.

# %%
df.columns = ['Title', 'ID', 'Price']

# %%
df.head()

# %% [markdown]
# We could do text anaylsis and see what words are common in ads which has a relatively higher price.

# %% [markdown]
# This approach is not really efficient because it only gets the first page of the search results. We see on the top of the CL page the total number of listings. In the `Inspection` mode we can pick an element from the page and check how it is defined in the `html` -- this is useful to get tags and classes efficiently.
#
# For example, the total number of ads is a `span` tag with a 'totalcount' `class`.

# %% [markdown]
# We can see if we start clicking on the 2nd nd 3rd pages of the results that there is a structure in how they are defined
#
# First page:
#
# https://newyork.craigslist.org/search/roo?query=east+village&availabilityMode=0
#
# Second page:
#
# https://newyork.craigslist.org/search/roo?s=120&availabilityMode=0&query=east%20village
#
# Third page:
#
# https://newyork.craigslist.org/search/roo?s=240&availabilityMode=0&query=east%20village
#
#
# The number after `roo?s=` in the domain specifies where the listings are starting from (not inclusive). In fact, if we modify it ourselves we can fine-tune the page starting from the corresponding listing and then showing 120 listings. Try it!
#
# We can also define the first page by puttig`s=0&` after `roo?` like this:
#
# https://newyork.craigslist.org/search/roo?s=0&availabilityMode=0&query=east%20village

# %%
# First we get the total number of listings in real time

# %%
# Next we write a loop to scrape all pages

# %%
df.head(15)

# %%
df.shape

# %%
df.tail(15)

# %% [markdown]
# We have scraped all the listings from CL in section "Rooms and Shares" for the East Village.

# %% [markdown]
# ## Exercise
#
# Suppose you have a couple of destinations in mind and you want to check the weather for each of them for this Friday. You want to get it from the [National Weather Service](http://www.weather.gov/).
#
# These are the places I want to check (suppose there are many more and you want to automate it):
#
# ```python
# locations = ['Bozeman, Montana', 'White Sands National Monument', 'Stanford University, California']
# ```
#
# It seems that the NWS is using latitude and longitude coordinates in its search.
#
# i.e. for White Sands
# http://forecast.weather.gov/MapClick.php?lat=32.38092788700044&lon=-106.4794398029997
#
# Would be cool to pass these on as arguments.
#
# After some Google fu (i.e. "latitude and longitude of location python") find a post by [Chris Albon](https://chrisalbon.com/python/geocoding_and_reverse_geocoding.html) which describes exactly what we want.
#
# > "Geocoding (converting a phyiscal address or location into latitude/longitude) and reverse geocoding (converting a lat/long to a phyiscal address or location)[...] Python offers a number of packages to make the task incredibly easy [...] use pygeocoder, a wrapper for Google's geo-API, to both geocode and reverse geocode.
#
# Install `pygeocoder` through `pip install pygeocoder` (from `conda` only the OSX version is available).

# %%
from pygeocoder import Geocoder

# %%
loc = Geocoder.geocode('Bozeman, Montana')
loc.coordinates

# %% [markdown]
# We can check whether it's working fine at http://www.latlong.net/

# %%
locations = 

coordinates =

# %%
for location, coordinate in zip(locations, coordinates):
    print('The coordinates of {} are:'.format(location), coordinate)

# %% [markdown]
# Define a dictionary (of dictionaries) for the parameters we want to pass to the GET request that we send to the NWS server.

# %%
keys = {}
for location, coordinate in zip(locations, coordinates):

# %%
keys

# %% [markdown]
# Recall the format of the url associated with a particular location
#
# http://forecast.weather.gov/MapClick.php?lat=32.38092788700044&lon=-106.4794398029997

# %%
url = ' http://forecast.weather.gov/MapClick.php'    
nws = requests.get(url, params=keys[locations[0]])

# %%
nws.status_code

# %% [markdown]
# Create a BeautifulSoup instance

# %%
nws_soup =

# %%
seven = nws_soup.find('div', id='seven-day-forecast-container')

# %%
data = []

for location in locations:
    # send GET request to the server
    nws = requests.get(url, params=keys[location])
    # create a BeautifulSoup isntance
    nws_soup = BeautifulSoup(nws.content, 'html.parser')
    
    # locate the part of the html file that contains the information of interest
    seven = nws_soup.find('div', id='seven-day-forecast-container')
    temp = seven.find(text='Friday').parent.parent.find('p', class_='temp temp-high').get_text()
    
    data.append([location, temp])

# %%
df_weather = pd.DataFrame(data, columns=['Location', 'Friday weather'])
df_weather
