# %% [markdown]
# # Intro: Python and Pandas

# %% [markdown]
# This notebook will provide you with a short introduction into the basic command in Python, and specifically the basic commands of the pandas packages that we will be using in class.
# You should have completed already the [DataCamp Intro to Python for Data Science](https://www.datacamp.com/courses/intro-to-python-for-data-science) course. It is free and takes about four hours. If you havn't done that course please consider this a helpful ressource to familiarize yourself with Python/Pandas.
# After the class you will be able to read in data from a database and execute basic data manipulations using Pandas.

# %% [markdown]
# ## Table of Contents
# 1. [General Remarks](#General-Remarks)
#     1. [Python Setup](#Python-Setup)
#     1. [Loading Data](#Load-the-Data)
# 1. [Data Analysis in Pandas](#Data-Analysis-in-Pandas)
#     1. [Displaying Data](#Displaying-Data)
#     1. [Subsetting Data](#Subsetting-Data)
#     1. [Statistics](#Statistics)
#     1. [Adding and Updating Data](#Adding-and-Updating-Data)
#     1. [Grouping and Aggregating Data](#Grouping-and-Aggregating-Data)
#     1. [Merging Dataframes](#Merging-Dataframes)
#     1. [Saving a CSV](#Saving-a-CSV)

# %% [markdown]
# ## General Remarks
# ---
#
# Python:
# * Is a high-level interpreted general purpose programming language named after the Monty Python British comedy troupe
# * Was created by Guido van Rossum, and is maintained by an open source community
# * Is the fifth most popular programming language
# * Is an object orientied language
# * Is use mostly in data science because it is powerful and fast, and is compatible with other languages
# * Runs everywhere, it's easy to learn, it's highly readable, open-source and its fast development time compared to other languages
# * Comes with a growing and always-improving list of open-source libraries for scientific programming, data manipulation, and data analysis (e.g., Numpy, Scipy, Pandas, Scikit-Learn, Statsmodels, Matplotlib, Seaborn, PyTables, etc.)
#
# IPython/Jupyter
# * Is an enhanced, interactive python interpreter that started as a grad school project by Fernando Perez.
# * Evolved into the IPython notebook, which allowed users to archive their code, figures, and analysis in a single document, making doing reproducible research and sharing said research much easier.
# * Other languages including but not limited to Julia, Python and R were included. This then led to a rebranding known as the Jupyter Project.

# %% [markdown]
# ### Python Setup

# %% [markdown]
# - In Python, we `import` packages. The `import` command allows us to use libraries created by others in our own work by "importing" them. You can think of importing a library as opening up a toolbox and pulling out a specific tool.
# - NumPy is short for numerical python. NumPy is a lynchpin in Python's scientific computing stack. Its strengths include a powerful *N*-dimensional array object, and a large suite of functions for doing numerical computing.
# - Pandas is a library in Python for data analysis that uses the DataFrame object from R which is similiar to a spreedsheet but allows you to do your analysis programaticaly rather than the point-and-click of Excel. It is a lynchpin of the PyData stack.
# - Psycopg2 or sqlalchemy are a python libraries for interfacing with a PostGreSQL database.
# - Matplotlib is the standard plotting library in python.
# `%matplotlib inline` is a so-called "magic" function of Jupyter that enables plots to be displayed inline with the code and text of a notebook.

# %% [markdown]
# #### This is how the start of a notebook might look like

# %%
# remember to put this line in your notebook, otherwise the visualization won't show up
# %pylab inline
# import the packages
# numpy for array and matrix computation
import numpy as np

# pandas for data analysis
import pandas as pd

# matplotlib and seaborn are the data visualization packages
import matplotlib.pyplot as plt
import seaborn as sns

# sqlalchemy an psycopg2 are sql connection packages
from sqlalchemy import create_engine

# configure pandas display: set the maximum number of columns displayed to 25
pd.options.display.max_columns = 25

# use the __future__ version of division and print
from __future__ import division, print_function
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# In practice we typically load libraries like `numpy` and `pandas` with shortened aliases, e.g, `import numpy as np`. This is like saying, "`import numpy`, and wherever you see `np`, read it as `numpy`." Similarly, you'll often see `import pandas as pd`, or `import matplotlib.pyplot as plt`.
#
# Another shortcut is `%pylab inline`. This command includes both `import numpy as np` and `import matplotlib.pyplot as plt `. This shortcut was invented because it's faster to type `plt.plot()` rather than `matplotlib.pyplot.plot()`, and even programmers don't like to type more than they have to.
#
# In documentation and in examples, you will frequently see `numpy` commands starting with the alias `np` rather than `numpy` (e.g, `np.array()` or `np.argsort`) and `pandas` commands starting with `pd` (e.g., `pd.DataFrame()` or `pd.concat()`).

# %% [markdown]
# ### Loading Data

# %% [markdown]
# Before we can start analysing the data we have to load it into memory. We can read in different kind of data formats. The Pandas package provides many ways to load data. It allows the user to read the data from a local csv or excel file, or pull the data from a relational database. Since we are working with the relational database ada_pub in this class, we will demonstrate how to use pandas to read data from a relational database. For examples to read data from a csv file, refert to the pandas documentation [Getting Data In/Out](pandas.pydata.org/pandas-docs/stable/10min.html#getting-data-in-out).
#
# The function to create a sql query and put the data into a pandas dataframe (more to come) is `pd.read_sql()`. This function will ask for some information about the database, and what query you would like to run.

# %% [markdown]
# ### Establish a connection to the ada_pub database
# In the most simple case, only 2 parameters are required by the `pd.read_sql()` function to pull data. The first parameter is the connection to the database, the second parameter the actual SQL query. To create a connection we use the sqlalchemy package and tell it which database we want to connect to.

# %% [markdown]
# #### Parameter 1: connection

# %%
# create postgresql connection - three '/' indicate to use default host, port, username, and password
engine = create_engine('postgresql:///ada_pub')

# %% [markdown]
# #### Parameter 2: query
# Depending on what data we are interested in, we can use different queries to pull different data. In this example, we will pull all the content of the table projects that we can find for agency USDA in year 2014. The three quotation marks surrounding the query body is called multi-line string. It is quite handy for writing sql queries because the new line character will be considered part of the string, instead of breaking the string

# %%
QUERY = '''
SELECT *
FROM projects
WHERE department = 'USDA' AND fy = '2014';
'''

# %% [markdown]
# ### Pull data from the database
# Now that we know what the arguments are for the query, we can pass them to the `pd.read_sql()` function, and obtain the data.

# %%
# here we pass the query and the connection to the pd.read_sql() function 
example=pd.read_sql_query(QUERY,con=engine)

# %%
example
# Out:
#       project_id                                      project_terms  \
# 0         589214   Bees; Chemicals; Development; Devices; Diet; ...
# 1         589224   Affect; Algae; Amendment; Appearance; base; B...
# 2         591601   Area; base; Biological; California; Consumpti...
# 3         593659   absorption; Address; Anemia; Anemia due to Ch...
# 4         597171   Climate; Decision Support Systems; Developmen...
# 5         599511   Attention; base; Development; Fisheries; Fish...
# 6         689200   Agriculture; Farming environment; New York; N...
# 7         690030   Animals; Embryo; Genome; programs; Research; ...
# 8         690062   Population; Population Growth; Process; Repro...
# 9         689214   Development; Growth; Lead; Nematoda; next gen...
# 10        689388   Agriculture; Cost Sharing; Data; economic imp...
# 11        690284   Biological; Nematoda; Plants; Production; Res...
# 12        689215   base; Bird Diseases; design; Diet; Genetic; G...
# 1     ALGAL-BASED WATER TREATMENT TECHNOLOGIES FOR S...       USDA    ARS
# 2     BIOLOGICAL CONTROL OF PIERCE'S DISEASE OF GRAP...       USDA   NIFA
# 3     MOLECULAR MECHSNISMS OF INTESTINAL METAL ION T...       USDA   NIFA
# 4     ASSESSING CLIMATE INFORMATION NEEDS AND OPPORT...       USDA   NIFA
# 5     DEVELOPMENT OF TOOLS TO ENABLE PLACE-BASED MAN...       USDA   NIFA
# 6     NITROGEN LOSSES FROM AGRICULTURE: COMPARING OR...       USDA   NIFA
# 7               NATIONAL ANIMAL GENOME RESEARCH PROGRAM       USDA   NIFA
# 8     DYNAMICS, PERSISTENCE AND MANAGEMENT OF VERTEB...       USDA   NIFA
# 9     ANALYSIS OF SEXUAL REPRODUCTION IN A ROOT-KNOT...       USDA   NIFA
# 10    ECONOMIC IMPACT OF VALUE-ADDED AGRICULTURE IN ...       USDA   NIFA
# 11    VARIABILITY, ADAPTATION, AND MANAGEMENT OF NEM...       USDA   NIFA
# 12    GENETIC BASES FOR RESISTANCE AND IMMUNITY TO A...       USDA   NIFA
# 13    MECHANISMS AND GENETICS OF REPRODUCTION IN INS...       USDA   NIFA
# 14                    ECONOMICS OF CROP BIOTECHNOLOGIES       USDA   NIFA
# 15    THE EFFECT OF OPTIMASE AND RUMENSIN ON BEEF CA...       USDA   NIFA
# 16                               HATCH ACT OF 1887 - NY       USDA   NIFA
# 17      ANIMAL HEALTH AND DISEASE RESEARCH PROGRAM - OH       USDA   NIFA
# 18    HATCH ACT OF 1887 (MULTISTATE RESEARCH FUND) - NY       USDA   NIFA
# 19                                   AGRABILITY OF UTAH       USDA   NIFA
# 20    SGU RESTORING THE BUFFALO ECONOMY EDUCATION PR...       USDA   NIFA
# 21    MCINTIRE-STENNIS COOPERATIVE FORESTRY RESEARCH...       USDA   NIFA
# 22    NATIVE BEES IN CRANBERRY AGROECOSYSTEMS: WHERE...       USDA   NIFA
# 23    ARE DIACYL RESORCINOLS THE UNKNOWN ANTIMICROBI...       USDA   NIFA
# 24    REFINING INSECT PEST MANAGEMENT FOR THE LOUISI...       USDA   NIFA
# 25    RESOURCE MANAGEMENT IN COMMERCIAL GREENHOUSE P...       USDA   NIFA
# 26    GREEN ROOF DESIGN AND MANAGEMENT PRACTICES TO ...       USDA   NIFA
# 27    IDENTIFYING FACTORS THAT REDUCE THE REPRODUCTI...       USDA   NIFA
# 28    ADVANCED TECHNOLOGIES FOR THE GENETIC IMPROVEM...       USDA   NIFA
# 29              FLAVOR DEVELOPMENT IN DISTILLED SPIRITS       USDA   NIFA
# ...                                                 ...        ...    ...
# 3162  BIOAVAILABILITY OF IRON, ZINC AND SELECT PHYTO...       USDA    ARS
# 3163  GENETIC AND GENOMIC APPROACHES TO IMPROVE SWIN...       USDA    ARS
# 3164  IMPROVEMENT OF POSTHARVEST PERFORMANCE OF ORNA...       USDA    ARS
# 3165  PREDICTIVE BIOLOGY OF EMERGING VECTOR-BORNE VI...       USDA    ARS
# 3166  IMPACT OF EARLY DIETARY FACTORS ON CHILD DEVEL...       USDA    ARS
# 3167  IMPROVING NUTRITION AND PHYSICAL ACTIVITY RELA...       USDA    ARS
# 3168  REGULATORY MECHANISMS INDUCED BY HEALTH-PROMOT...       USDA    ARS
# 3169    DIETARY REGULATION OF IMMUNITY AND INFLAMMATION       USDA    ARS
# 3170  HEALTH PROMOTING ROLES OF FOOD BIO-ACTIVE PHEN...       USDA    ARS
# 3171  USDA NATIONAL NUTRIENT DATABANK FOR FOOD COMPO...       USDA    ARS
# 3172  DEVELOPING TECHNOLOGIES THAT ENABLE GROWTH AND...       USDA    ARS
# 3173                CARDIOVASCULAR NUTRITION AND HEALTH       USDA    ARS
# 3174                       VISION, AGING, AND NUTRITION       USDA    ARS
# 3175  NOVEL FUNCTIONS AND BIOMARKERS FOR VITAMINS AN...       USDA    ARS
# 3176        USDA DIETARY SUPPLEMENT INGREDIENT DATABASE       USDA    ARS
# 3177  DETECTION AND IDENTIFICATION OF SOIL-BORNE PLA...       USDA    ARS
# 3178                                  RURAL AGING STUDY       USDA    ARS
# 3179  ASSESSING THE IMPACT OF DIET ON INFLAMMATION I...       USDA    ARS
# 3180                   INVASIVE ANT BIOLOGY AND CONTROL       USDA    ARS
# 3181  IMPROVING PUBLIC HEALTH BY UNDERSTANDING DIVER...       USDA    ARS
# 3182           FUSARIUM HEAD BLIGHT OF WHEAT AND BARLEY       USDA    ARS
# 3183  REDUCING ANIMAL STRESS AND THE INCIDENCE OR PR...       USDA    ARS
# 3184                        GENOMICS OF LIVESTOCK PESTS       USDA    ARS
# 3185  APPLICATION TECHNOLOGIES TO IMPROVE THE EFFECT...       USDA    ARS
# 3186  DEVELOPMENT OF PRODUCTIVE, PROFITABLE, AND SUS...       USDA    ARS
# 3187  TECHNOLOGIES FOR IMPROVING PROCESS EFFICIENCIE...       USDA    ARS
# 3188  BIOCHEMICAL TECHNOLOGIES TO ENABLE THE COMMERC...       USDA    ARS
# 3189  DEVELOP TECHNOLOGIES FOR PRODUCTION OF PLATFOR...       USDA    ARS
# 3190  ENABLE NEW MARKETABLE, VALUE-ADDED COPRODUCTS ...       USDA    ARS
# 3191  NEW BIOBASED PRODUCTS AND IMPROVED BIOCHEMICAL...       USDA    ARS
#
#      ic_center    project_number project_start_date project_end_date  \
# 0         None       ARS-0425868          10/1/2013         2/6/2014
# 1         None       ARS-0426136           1/1/2014       12/31/2018
# 2         None           0212205          8/20/2014        9/30/2014
# 3         None           0217191           7/8/2014         7/9/2014
# 4         None           0226918          8/19/2014        8/20/2014
# 5         None           0233896          5/30/2014        9/30/2018
# 6         None           1000965          10/1/2013        9/30/2016
# 7         None           1002276           1/6/2014        9/30/2018
# 8         None           1002321          1/28/2014       12/23/2018
# 9         None           1001006           1/6/2014        9/30/2018
# 10        None           1001368          10/1/2013        9/30/2018
# 11        None           1002704           3/7/2014        9/30/2018
# 12        None           1001007          10/1/2013        9/30/2018
# 13        None           1001426          10/1/2013        9/30/2018
# 14        None           1001427          10/1/2013        9/30/2015
# 15        None           1001905          11/7/2013        9/30/2018
# 17                SLACK, STEVEN A.
# 18                 BURR, THOMAS J.
# 19                  MILLER, RHONDA
# 20                 BORDEAUX, SHAWN
# 21               ZIMMERMAN, THOMAS
# 22                     GRATTON, C.
# 23                    ANDERSON, A.
# 24                    BEUZELIN, J.
# 25                      KRUG, B, .
# 26                        ROWE, D.
# 27                       TARPY, D.
# 28                 FROMAN, DA, PA.
# 29                    BERGLUND, K.
# ...                            ...
# 3162              GLAHN, RAYMOND P
# 3163                ROHRER, GARY A
# 3164              JIANG, CAI ZHONG
# 3165            MCVEY, DAVID SCOTT
# 3166            BRENNAN, DEBORAH L
# 3167            THOMSON, JESSICA L
# 3168               WANG, THOMAS TY
# 3169               DAWSON, HARRY D
# 3170                   PARK, JAE B
# 3171                          None
# 3172            EGGLESTON, GILLIAN
# 3173           SWIETLIK, DARIUSZ M
# 3174           SWIETLIK, DARIUSZ M
# 3175                 HUANG, LIPING
# 3176            PEHRSSON, PAMELA R
# 3177             LAKSHMAN, DILIP K
# 3178           SWIETLIK, DARIUSZ M
# 3179         STEPHENSEN, CHARLES B
# 3180              VALLES, STEVEN M
# 3181         BENNETT, BRIAN JOSEPH
# 3182                   COSTA, JOSE
# 3183               EICHER, SUSAN D
# 3184            GUERRERO, FELICITO
# 3185                  HUANG, YANBO
# 3186        REDDY, KRISHNA NARASIM
# 3187                 DIEN, BRUCE S
# 3188  SLININGER, PATRICIA J WATSON
# 3189                 SAHA, BADAL C
# 3190              MOREAU, ROBERT A
# 3191           BISCHOFF, KENNETH M
#
#                                            other_pis  congressional_district  \
# 0                                               None                     2.0
# 1                                               None                     0.0
# 2                                               None                     NaN
# 3                                               None                     NaN
# 4                                               None                     NaN
# 5                                               None                     NaN
# 6                                     MARINO, RO, M                      NaN
# 7                                               None                     NaN
# 8                                        OLI, MA, K                      NaN
# 9                                       BRITT, AN,                       NaN
# 10                                              None                     NaN
# 11                                              None                     NaN
# 12                                              None                     NaN
# 13                                              None                     NaN
# 14                                              None                     NaN
# 15                      HORN, GE,  ; RICHARDS, CH,                       NaN
# 16                                              None                    23.0
# 17                                              None                    16.0
# 18                                              None                    23.0
# 19                     PATE, MICHAEL; JOHNSON, TRACY                     1.0
# 20                            REDOWL-NEISS, SHERRY D                     0.0
# 21                                              None                     0.0
# 22                                              None                     NaN
# 23                                              None                     NaN
# 24                                              None                     NaN
# 25                                              None                     NaN
# 26    ANDRESEN, JE,  ; CAMPA, HE,  ; WESTPHAL, JO,                       NaN
# 27                                              None                     NaN
# 28                                              None                     NaN
# 29                                              None                     NaN
# ...                                              ...                     ...
# 3162                                            None                    23.0
# 3163                                            None                     3.0
# 3164                                            None                     4.0
# 3165                                            None                     1.0
# 3166                                            None                     2.0
# 3167                                            None                     2.0
# 3168                                            None                     5.0
# 3169                                            None                     5.0
# 3170                                            None                     5.0
# 3171                                            None                     5.0
# 3172                                            None                     1.0
# 3173                                            None                     7.0
# 3174                                            None                     7.0
# 3175                                            None                     4.0
# 3176                                            None                     5.0
# 3177                                            None                     0.0
# 3176   136617730                      AGRICULTURAL RESEARCH SERVICE
# 3177        None                      AGRICULTURAL RESEARCH SERVICE
# 3178        None                      AGRICULTURAL RESEARCH SERVICE
# 3179        None                      AGRICULTURAL RESEARCH SERVICE
# 3180        None                      AGRICULTURAL RESEARCH SERVICE
# 3181        None                      AGRICULTURAL RESEARCH SERVICE
# 3182   136617730                      AGRICULTURAL RESEARCH SERVICE
# 3183        None                      AGRICULTURAL RESEARCH SERVICE
# 3184        None                      AGRICULTURAL RESEARCH SERVICE
# 3185   136617730                      AGRICULTURAL RESEARCH SERVICE
# 3186   136617730                      AGRICULTURAL RESEARCH SERVICE
# 3187   064539612                 U.S. AGRICULTURAL RESEARCH SERVICE
# 3188   064539612                 U.S. AGRICULTURAL RESEARCH SERVICE
# 3189   064539612                 U.S. AGRICULTURAL RESEARCH SERVICE
# 3190        None                      AGRICULTURAL RESEARCH SERVICE
# 3191   064539612                 U.S. AGRICULTURAL RESEARCH SERVICE
#
#      organization_city organization_state organization_zip  \
# 0               TUCSON                 AZ            85719
# 1          FORT PIERCE                 FL            34945
# 2          GAINESVILLE                 FL       32611-0110
# 3          GAINESVILLE                 FL       32611-0110
# 4          GAINESVILLE                 FL       32611-0110
# 5          GAINESVILLE                 FL       32611-0110
# 6             ORISKANY                 NY       13424-3921
# 7               DENVER                 CO       80203-1148
# 8          GAINESVILLE                 FL       32611-0110
# 9                DAVIS                 CA       95618-6153
# 10             RALEIGH                 NC       27695-0001
# 11              AUBURN                 AL       36849-0001
# 12               DAVIS                 CA       95618-6153
# 13           MANHATTAN                 KS       66506-1109
# 14             RALEIGH                 NC       27695-0001
# 15          STILLWATER                 OK       74078-1030
# 16              ITHACA                 NY       14850-2820
# 17             WOOSTER                 OH       44691-0000
# 18              ITHACA                 NY       14850-2820
# 19               LOGAN                 UT       84322-0000
# 20             MISSION                 SD       57555-0000
# 21           ST THOMAS                 VI          8029990
# 22             MADISON                 WI       53706-1415
# 23               LOGAN                 UT       84322-0001
# 24          SHREVEPORT                 LA       71115-2301
# 25                 LEE                 NH       03861-6659
# 26        EAST LANSING                 MI       48824-1046
# 27             RALEIGH                 NC       27695-0001
# 28           CORVALLIS                 OR            97331
# 29        EAST LANSING                 MI       48824-1046
# ...                ...                ...              ...
# 3162            ITHACA                 NY            14853
# 3163       CLAY CENTER                 NE            68933
# 3164             DAVIS                 CA            95616
# 3165         MANHATTAN                 KS            66506
# 3166       LITTLE ROCK                 AR            72204
# 3167        STONEVILLE                 MS            38776
# 3168        BELTSVILLE                 MD            20705
# 3169        BELTSVILLE                 MD            20705
# 3170        BELTSVILLE                 MD            20705
# 3171        BELTSVILLE                 MD            20705
# 3172       NEW ORLEANS                 LA       70124-4305
# 3173            BOSTON                 MA            02111
# 3174            BOSTON                 MA            02111
# 3175             DAVIS                 CA            95616
# 3176        BELTSVILLE                 MD            20705
# 3177        WASHINGTON                 DC            20002
# 3178            BOSTON                 MA            02111
# 3179             DAVIS                 CA            95616
# 3180       GAINESVILLE                 FL            32608
# 3186        UNITED STATES              None            None    10.001  2014
# 3187        UNITED STATES              None            None    10.001  2014
# 3188        UNITED STATES              None            None    10.001  2014
# 3189        UNITED STATES              None            None    10.001  2014
# 3190        UNITED STATES              None            None    10.001  2014
# 3191        UNITED STATES              None            None    10.001  2014
#
#       fy_total_cost fy_total_cost_sub_projects
# 0               NaN                       None
# 1               NaN                       None
# 2               NaN                       None
# 3               NaN                       None
# 4               NaN                       None
# 5               NaN                       None
# 6               NaN                       None
# 7               NaN                       None
# 8               NaN                       None
# 9               NaN                       None
# 10              NaN                       None
# 11              NaN                       None
# 12              NaN                       None
# 13              NaN                       None
# 14              NaN                       None
# 15              NaN                       None
# 16         490142.0                       None
# 17          56954.0                       None
# 18         765728.0                       None
# 19         180000.0                       None
# 20         107468.0                       None
# 21          44900.0                       None
# 22              NaN                       None
# 23              NaN                       None
# 24              NaN                       None
# 25              NaN                       None
# 26              NaN                       None
# 27              NaN                       None
# 28              NaN                       None
# 29              NaN                       None
# ...             ...                        ...
# 3162       962419.0                       None
# 3163      1279060.0                       None
# 3164       260371.0                       None
# 3165       895500.0                       None
# 3166      7759400.0                       None
# 3167       428981.0                       None
# 3168      1134740.0                       None
# 3169      1384270.0                       None
# 3170      1074021.0                       None
# 3171      3705775.0                       None
# 3172      2263140.0                       None
# 3173      1320812.0                       None
# 3174       867215.0                       None
# 3175       473684.0                       None
# 3176       158548.0                       None
# 3177       219371.0                       None
# 3178       167130.0                       None
# 3179      2714120.0                       None
# 3180      2169831.0                       None
# 3181      3081852.0                       None
# 3182            NaN                       None
# 3183       487483.0                       None
# 3184      2037751.0                       None
# 3185      1144645.0                       None
# 3186      1378672.0                       None
# 3187      1345714.0                       None
# 3188       833060.0                       None
# 3189      1281630.0                       None
# 3190      2133178.0                       None
# 3191      1547666.0                       None
#
# [3192 rows x 24 columns]

# %% [markdown]
# By now we have finished loading the data, and we are ready to do some data analysis

# %% [markdown]
# ## Data Analysis in Pandas

# %% [markdown]
# When we are working with Pandas we are thinking in terms of dataframes. It's a pandas representation of a spreadsheet/ sql table/Stata/R or SAS dataset. It contains information such as column names, row indices (starting from 0), and the actual data. They are the basic objects on which we will perform our data analysis.

# %% [markdown]
# ### Displaying Data

# %% [markdown]
# #### The shape of the dataframe
# When we get the data, we usually want to know how many rows and columns are there in the data. We can find out the row and column numbers by calling the shape instance variable with a dot operator.

# %%
# shape of a dataframe (row number, column number)
example.shape
# We can see that the dataframe contains 3192 rows, and 24 columns
# Out:
# (3192, 24)

# %%
# See the list of variables in data
example.count()
# Out:
# project_id                    3192
# project_terms                 3192
# project_title                 3192
# department                    3192
# agency                        3192
# ic_center                        0
# project_number                3192
# project_start_date            3192
# project_end_date              3192
# contact_pi_project_leader     3180
# other_pis                     1072
# congressional_district        1360
# duns_number                   2894
# organization_name             3189
# organization_city             3189
# organization_state            3189
# organization_zip              3087
# organization_country          3192
# budget_start_date                0
# budget_end_date                  0
# cfda_code                     3192
# fy                            3192
# fy_total_cost                 1005
# fy_total_cost_sub_projects       0
# dtype: int64

# %% [markdown]
# #### The head and tail of the dataframe
# It is also helpful to have a look at the first or last few rows of the data for a first impression, as well as a sanity check. We can call the head()/tail() methods. We can also specify how many lines we would like to see in the parentheses at the end. We choose to display 10. If not specified, by default the first 5 lines will be returned

# %%
# display the first few rows of the dataframe
example.head(10)
# Out:
#    project_id                                      project_terms  \
# 0      589214   Bees; Chemicals; Development; Devices; Diet; ...
# 1      589224   Affect; Algae; Amendment; Appearance; base; B...
# 2      591601   Area; base; Biological; California; Consumpti...
# 3      593659   absorption; Address; Anemia; Anemia due to Ch...
# 4      597171   Climate; Decision Support Systems; Developmen...
# 5      599511   Attention; base; Development; Fisheries; Fish...
# 6      689200   Agriculture; Farming environment; New York; N...
# 7      690030   Animals; Embryo; Genome; programs; Research; ...
# 8      690062   Population; Population Growth; Process; Repro...
# 9      689214   Development; Growth; Lead; Nematoda; next gen...
#
#                                        project_title department agency  \
# 0  IMPROVE NUTRITION FOR HONEY BEE COLONIES TO ST...       USDA    ARS
# 1  ALGAL-BASED WATER TREATMENT TECHNOLOGIES FOR S...       USDA    ARS
# 2  BIOLOGICAL CONTROL OF PIERCE'S DISEASE OF GRAP...       USDA   NIFA
# 3  MOLECULAR MECHSNISMS OF INTESTINAL METAL ION T...       USDA   NIFA
# 4  ASSESSING CLIMATE INFORMATION NEEDS AND OPPORT...       USDA   NIFA
# 5  DEVELOPMENT OF TOOLS TO ENABLE PLACE-BASED MAN...       USDA   NIFA
# 6  NITROGEN LOSSES FROM AGRICULTURE: COMPARING OR...       USDA   NIFA
# 7            NATIONAL ANIMAL GENOME RESEARCH PROGRAM       USDA   NIFA
# 8  DYNAMICS, PERSISTENCE AND MANAGEMENT OF VERTEB...       USDA   NIFA
# 9  ANALYSIS OF SEXUAL REPRODUCTION IN A ROOT-KNOT...       USDA   NIFA
#
#   ic_center project_number project_start_date project_end_date  \
# 0      None    ARS-0425868          10/1/2013         2/6/2014
# 1      None    ARS-0426136           1/1/2014       12/31/2018
# 2      None        0212205          8/20/2014        9/30/2014
# 3      None        0217191           7/8/2014         7/9/2014
# 4      None        0226918          8/19/2014        8/20/2014
# 5      None        0233896          5/30/2014        9/30/2018
# 6      None        1000965          10/1/2013        9/30/2016
# 7      None        1002276           1/6/2014        9/30/2018
# 8      None        1002321          1/28/2014       12/23/2018
# 9      None        1001006           1/6/2014        9/30/2018
#
#   contact_pi_project_leader       other_pis  congressional_district  \
# 0         HOFFMAN, GLORIA D            None                     2.0
# 1      HALL, DAVID GOODSELL            None                     0.0
# 2            HOPKINS, DO, .            None                     NaN
# 3          COLLINS, JA, F..            None                     NaN
# 4                 JONES, J.            None                     NaN
# 5             STRUVE, JU, .            None                     NaN
# 6              HOWARTH, RO.  MARINO, RO, M                      NaN
# 7              BRUEMMER, J.            None                     NaN
# 8                   OLI, M.     OLI, MA, K                      NaN
# 9            ENGEBRECHT, J.    BRITT, AN,                       NaN
#
#   duns_number                                  organization_name  \
# 0   078274365  HONEY BEE RESEARCH INSTITUTE AND NATURE CENTER...
# 1        None      SUBTROPICAL INSECTS AND HORTICULTURE RESEARCH
# 2   002236250                              UNIVERSITY OF FLORIDA
# 3   002236250                              UNIVERSITY OF FLORIDA
# 4   002236250                              UNIVERSITY OF FLORIDA
# 5   002236250                              UNIVERSITY OF FLORIDA
# 6   613809599                             CORNELL UNIVERSITY INC
# 7   149546160                          COLORADO STATE UNIVERSITY
# 8   002236250                              UNIVERSITY OF FLORIDA
# 9   047120084                     UNIVERSITY OF CALIFORNIA DAVIS
#
#   organization_city organization_state organization_zip organization_country  \
# 0            TUCSON                 AZ            85719        UNITED STATES
# 1       FORT PIERCE                 FL            34945        UNITED STATES
# 2       GAINESVILLE                 FL       32611-0110        UNITED STATES
# 3       GAINESVILLE                 FL       32611-0110        UNITED STATES
# 4       GAINESVILLE                 FL       32611-0110        UNITED STATES
# 5       GAINESVILLE                 FL       32611-0110        UNITED STATES
# 6          ORISKANY                 NY       13424-3921        UNITED STATES
# 7            DENVER                 CO       80203-1148        UNITED STATES
# 8       GAINESVILLE                 FL       32611-0110        UNITED STATES
# 9             DAVIS                 CA       95618-6153        UNITED STATES
#
#   budget_start_date budget_end_date cfda_code    fy  fy_total_cost  \
# 0              None            None    10.001  2014            NaN
# 1              None            None    10.001  2014            NaN
# 2              None            None    10.203  2014            NaN
# 3              None            None    10.203  2014            NaN
# 4              None            None    10.202  2014            NaN
# 5              None            None    10.203  2014            NaN
# 6              None            None    10.203  2014            NaN
# 7              None            None    10.203  2014            NaN
# 8              None            None    10.203  2014            NaN
# 9              None            None    10.203  2014            NaN
#
#   fy_total_cost_sub_projects
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# 5                       None
# 6                       None
# 7                       None
# 8                       None
# 9                       None

# %%
# last few rows of the dataframe
# the syntax is similar to head
example.tail()
# Out:
#       project_id                                      project_terms  \
# 3187      813637   Acids; Affect; Aldehydes; Beta-glucuronidase;...
# 3188      813638   base; Biochemical; Biomass; Collaborations; E...
# 3189      813639   Acids; Arabinose; Aspergillus; Butanols; carb...
# 3190      813643   Agriculture; antimicrobial; Antioxidants; bas...
# 3191      813655   Agriculture; Anti-Bacterial Agents; Bacteria;...
#
#                                           project_title department agency  \
# 3187  TECHNOLOGIES FOR IMPROVING PROCESS EFFICIENCIE...       USDA    ARS
# 3188  BIOCHEMICAL TECHNOLOGIES TO ENABLE THE COMMERC...       USDA    ARS
# 3189  DEVELOP TECHNOLOGIES FOR PRODUCTION OF PLATFOR...       USDA    ARS
# 3190  ENABLE NEW MARKETABLE, VALUE-ADDED COPRODUCTS ...       USDA    ARS
# 3191  NEW BIOBASED PRODUCTS AND IMPROVED BIOCHEMICAL...       USDA    ARS
#
#      ic_center project_number project_start_date project_end_date  \
# 3187      None    ARS-0427437           8/9/2014         8/8/2019
# 3188      None    ARS-0427438          8/21/2014        8/20/2019
# 3189      None    ARS-0427439          8/29/2014        8/28/2019
# 3190      None    ARS-0427684           9/8/2014         9/7/2019
# 3191      None    ARS-0427980          9/19/2014        9/18/2019
#
#          contact_pi_project_leader other_pis  congressional_district  \
# 3187                 DIEN, BRUCE S      None                    18.0
# 3188  SLININGER, PATRICIA J WATSON      None                    18.0
# 3189                 SAHA, BADAL C      None                    18.0
# 3190              MOREAU, ROBERT A      None                    13.0
# 3191           BISCHOFF, KENNETH M      None                    18.0
#
#      duns_number                   organization_name organization_city  \
# 3187   064539612  U.S. AGRICULTURAL RESEARCH SERVICE            PEORIA
# 3188   064539612  U.S. AGRICULTURAL RESEARCH SERVICE            PEORIA
# 3189   064539612  U.S. AGRICULTURAL RESEARCH SERVICE            PEORIA
# 3190        None       AGRICULTURAL RESEARCH SERVICE          WYNDMOOR
# 3191   064539612  U.S. AGRICULTURAL RESEARCH SERVICE            PEORIA
#
#      organization_state organization_zip organization_country  \
# 3187                 IL            61604        UNITED STATES
# 3188                 IL            61604        UNITED STATES
# 3189                 IL            61604        UNITED STATES
# 3190                 PA            19038        UNITED STATES
# 3191                 IL            61604        UNITED STATES
#
#      budget_start_date budget_end_date cfda_code    fy  fy_total_cost  \
# 3187              None            None    10.001  2014      1345714.0
# 3188              None            None    10.001  2014       833060.0
# 3189              None            None    10.001  2014      1281630.0
# 3190              None            None    10.001  2014      2133178.0
# 3191              None            None    10.001  2014      1547666.0
#
#      fy_total_cost_sub_projects
# 3187                       None
# 3188                       None
# 3189                       None
# 3190                       None
# 3191                       None

# %% [markdown]
# ### Columns, rows, data selection

# %% [markdown]
# #### Column names
# to see which columns are there in the data, use the following syntax.

# %%
example.columns
# Out:
# Index([u'project_id', u'project_terms', u'project_title', u'department',
#        u'agency', u'ic_center', u'project_number', u'project_start_date',
#        u'project_end_date', u'contact_pi_project_leader', u'other_pis',
#        u'congressional_district', u'duns_number', u'organization_name',
#        u'organization_city', u'organization_state', u'organization_zip',
#        u'organization_country', u'budget_start_date', u'budget_end_date',
#        u'cfda_code', u'fy', u'fy_total_cost', u'fy_total_cost_sub_projects'],
#       dtype='object')

# %% [markdown]
# #### Single column selection
# If we want to select a specific column, we can use the following syntax:

# %%
# select a single column: the dataframe variable name, followed by square brackets, and then put the
# the column name between quotes (either single or double). 
example['agency'].head()
# Out:
# 0     ARS
# 1     ARS
# 2    NIFA
# 3    NIFA
# 4    NIFA
# Name: agency, dtype: object

# %%
# the same would be
example.agency.head()
# Out:
# 0     ARS
# 1     ARS
# 2    NIFA
# 3    NIFA
# 4    NIFA
# Name: agency, dtype: object

# %% [markdown]
# #### Multiple-column selection
# to select multiple columns, wrap the column names in a python list, then put the list or tuple between the brackets after the dataframe

# %%
# here we selected the columns and assigned them to a new dataframe example2
example2 = example[['agency', 'project_title', 'fy_total_cost',
                           'project_start_date','project_end_date']]
example2.head()
# Out:
#   agency                                      project_title  fy_total_cost  \
# 0    ARS  IMPROVE NUTRITION FOR HONEY BEE COLONIES TO ST...            NaN
# 1    ARS  ALGAL-BASED WATER TREATMENT TECHNOLOGIES FOR S...            NaN
# 2   NIFA  BIOLOGICAL CONTROL OF PIERCE'S DISEASE OF GRAP...            NaN
# 3   NIFA  MOLECULAR MECHSNISMS OF INTESTINAL METAL ION T...            NaN
# 4   NIFA  ASSESSING CLIMATE INFORMATION NEEDS AND OPPORT...            NaN
#
#   project_start_date project_end_date
# 0          10/1/2013         2/6/2014
# 1           1/1/2014       12/31/2018
# 2          8/20/2014        9/30/2014
# 3           7/8/2014         7/9/2014
# 4          8/19/2014        8/20/2014

# %% [markdown]
# #### single/ multiple cell(s) selection
# Use the `loc` method for cell selection. Pass the row and column indices in the _square brackets_ after `loc`. Specify the row index first, and then column name, separated by a comma. Note that both indices will be included.

# %%
# single cell selection
# select the cell in row 5 and column rootrace
cell = example2.loc[3, 'project_start_date']
cell
# Out:
# u'7/8/2014'

# %%
# multiple cells selection
# option 1: use a python list to explicitly list the rows/columns
cell = example2.loc[[0, 2, 4], 'project_start_date']
cell
# Out:
# 0    10/1/2013
# 2    8/20/2014
# 4    8/19/2014
# Name: project_start_date, dtype: object

# %%
# option 2: use colon to indicate contiguous selection
cell = example2.loc[0:4, 'project_start_date']
cell
# Out:
# 0    10/1/2013
# 1     1/1/2014
# 2    8/20/2014
# 3     7/8/2014
# 4    8/19/2014
# Name: project_start_date, dtype: object

# %%
# if we want to select all columns, we can use a colon symbol :.
row5 = example2.loc[5, :]
row5
# Out:
# agency                                                             NIFA
# project_title         DEVELOPMENT OF TOOLS TO ENABLE PLACE-BASED MAN...
# fy_total_cost                                                       NaN
# project_start_date                                            5/30/2014
# project_end_date                                              9/30/2018
# Name: 5, dtype: object

# %% [markdown]
# ### Subsetting Data
# #### Subsetting numerical data
# Similar to the `where` statement in sql, we can also select only data that meet certain condition. Depending on whether the data is numberical or string, we should choose to use different syntax for each situation. For example, if we would like to select columns that start from year 2015, we can use a larger than or equal to operator condition to subset.

# %%
# conditional subsetting: put the conditional statement within the square brackets 
# the conditional statement here is that we want the cost to be higher than or equal to 50.0000.
example3 = example2[example2['fy_total_cost'] >= 50000]
example3.head()
# Out:
#    agency                                      project_title  fy_total_cost  \
# 16   NIFA                             HATCH ACT OF 1887 - NY       490142.0
# 17   NIFA    ANIMAL HEALTH AND DISEASE RESEARCH PROGRAM - OH        56954.0
# 18   NIFA  HATCH ACT OF 1887 (MULTISTATE RESEARCH FUND) - NY       765728.0
# 19   NIFA                                 AGRABILITY OF UTAH       180000.0
# 20   NIFA  SGU RESTORING THE BUFFALO ECONOMY EDUCATION PR...       107468.0
#
#    project_start_date project_end_date
# 16          6/15/2013        2/14/2014
# 17           1/1/2013       12/31/2013
# 18           7/1/2013        2/28/2014
# 19          2/15/2014        2/14/2016
# 20           3/1/2014        2/28/2017

# %% [markdown]
# #### Subsetting string/categorical data
# When the column contains string data or categorical data, the comparison operators might not be the choice for data selection. Instead, we can compare each data in a column to a target list to see if the data in column is included in the list. This is done by calling the `isin` method.

# %%
# select specific agencies
# we specify the target list within the parentheses of the `isin` method
example4 = example2[example2['agency'].isin(['NIFA', 'ARS'])]
example4.head()
# Out:
#   agency                                      project_title  fy_total_cost  \
# 0    ARS  IMPROVE NUTRITION FOR HONEY BEE COLONIES TO ST...            NaN
# 1    ARS  ALGAL-BASED WATER TREATMENT TECHNOLOGIES FOR S...            NaN
# 2   NIFA  BIOLOGICAL CONTROL OF PIERCE'S DISEASE OF GRAP...            NaN
# 3   NIFA  MOLECULAR MECHSNISMS OF INTESTINAL METAL ION T...            NaN
# 4   NIFA  ASSESSING CLIMATE INFORMATION NEEDS AND OPPORT...            NaN
#
#   project_start_date project_end_date
# 0          10/1/2013         2/6/2014
# 1           1/1/2014       12/31/2018
# 2          8/20/2014        9/30/2014
# 3           7/8/2014         7/9/2014
# 4          8/19/2014        8/20/2014

# %% [markdown]
# #### Subsetting with multiple conditions
# If we want to subset the data with more than one condition, we can specify all the conditions and concatenate them with the python keyword `&`. Remember to put every single condition within a pair of parentheses.

# %%
# combine both selections from above
example5 = example2[(example2['fy_total_cost'] >= 50000) &
                        (example2['agency'].isin(['NIFA', 'ARS']))]
example5.head()
# Out:
#    agency                                      project_title  fy_total_cost  \
# 16   NIFA                             HATCH ACT OF 1887 - NY       490142.0
# 17   NIFA    ANIMAL HEALTH AND DISEASE RESEARCH PROGRAM - OH        56954.0
# 18   NIFA  HATCH ACT OF 1887 (MULTISTATE RESEARCH FUND) - NY       765728.0
# 19   NIFA                                 AGRABILITY OF UTAH       180000.0
# 20   NIFA  SGU RESTORING THE BUFFALO ECONOMY EDUCATION PR...       107468.0
#
#    project_start_date project_end_date
# 16          6/15/2013        2/14/2014
# 17           1/1/2013       12/31/2013
# 18           7/1/2013        2/28/2014
# 19          2/15/2014        2/14/2016
# 20           3/1/2014        2/28/2017

# %% [markdown]
# ### Statistics
# #### Descriptive stats
# Pandas has integrated some very useful tools to help us understand the distribution of the data. The `describe` method computes the most commonly used descriptive statistics, such as count, mean, standard deviation and quantiles for a dataframe.

# %%
# see the descriptive statistics of the wage column
example.describe()
# Out:
#           project_id  congressional_district      fy  fy_total_cost
# count    3192.000000             1360.000000  3192.0   1.005000e+03
# mean   698709.102130                5.024265  2014.0   6.858399e+05
# std     31939.102729                8.888327     0.0   1.077847e+06
# min    589214.000000                0.000000  2014.0   2.363000e+03
# 25%    688547.500000                1.000000  2014.0   1.000000e+05
# 50%    689477.500000                3.000000  2014.0   2.499830e+05
# 75%    690275.250000                5.000000  2014.0   7.680000e+05
# max    813655.000000               98.000000  2014.0   7.759400e+06

# %% [markdown]
# #### Value counts and unique values
# For categorical values, it is often helpful to figure out what are the unique values of a given column, and the quantity of each data. Let's go back to the welfare data

# %%
# find out how many different agencies are there in the data
example['agency'].unique()
# Out:
# array([u'ARS', u'NIFA', u'FS'], dtype=object)

# %%
# to count how many observations for each agency appeared in the data
example['agency'].value_counts()
# Out:
# NIFA    2896
# FS       184
# ARS      112
# Name: agency, dtype: int64

# %% [markdown]
# We know from the data dictionary that 0 represent not applicable, 1 represents white, not of hispanic origin, 2 represents black, not of hispanic origin, etc. So we can see from the data that most race information is not available in the welfare data.

# %% [markdown]
# ### Adding and Updating Data
# #### Creating columns
# We sometimes need to creat a new column, either to save the previously calculation from other columns, or add new information to the dataframe. The syntax is given below:
# `dataframe['column_name'] = value`
# where:
# dataframe is the dataframe in which the new column is created,
# column_name is the string of the new column name,
# value is the value of the each cell.

# %%
# we can then calculate the monthly cost by dividing the project costs column by 12, 
# and assign this newly computed column to the monthly column
example5['monthly'] = example5['fy_total_cost']/12
example5.head()
# Out:
#    agency                                      project_title  fy_total_cost  \
# 16   NIFA                             HATCH ACT OF 1887 - NY       490142.0
# 17   NIFA    ANIMAL HEALTH AND DISEASE RESEARCH PROGRAM - OH        56954.0
# 18   NIFA  HATCH ACT OF 1887 (MULTISTATE RESEARCH FUND) - NY       765728.0
# 19   NIFA                                 AGRABILITY OF UTAH       180000.0
# 20   NIFA  SGU RESTORING THE BUFFALO ECONOMY EDUCATION PR...       107468.0
#
#    project_start_date project_end_date       monthly
# 16          6/15/2013        2/14/2014  40845.166667
# 17           1/1/2013       12/31/2013   4746.166667
# 18           7/1/2013        2/28/2014  63810.666667
# 19          2/15/2014        2/14/2016  15000.000000
# 20           3/1/2014        2/28/2017   8955.666667

# %% [markdown]
# ### Grouping and Aggregating Data
# #### Group by and aggregation functions
# Like in SQL, it is also possible to group the dataframe by a column, and use aggregation function on them, and sort the result

# %%
# calculate the how many grats each agency funded
# step1: in the groupby method, we pass the column we want to group by, we can also select what columns
# we want to carry out the operation
# step2: use the count method to count the number of cases
# step3: sort the value in descending order (set the ascending parameter to False)
example.groupby('agency')['project_title'].count().sort_values(ascending=False)
# Out:
# agency
# NIFA    2896
# FS       184
# ARS      112
# Name: project_title, dtype: int64

# %% [markdown]
# Other useful aggregation functions are:
# sum(): sum
# mean(): average
# agg(): use a python dictionary to specify aggregation function based on each column

# %% [markdown]
# ### Merging Dataframes
# Pandas provides an ability to merge (join) two datasets together, like you can do in SQL. You can store the results in a new dataframe.

# %%
merge_df = pd.merge(example2, example3, on=["project_title", "second var"], how="inner")
merge_df.head()
# Out:
#   agency_x                                    project_title  fy_total_cost_x  \
# 0     NIFA                           HATCH ACT OF 1887 - NY         490142.0
# 1     NIFA                           HATCH ACT OF 1887 - NY         490142.0
# 2     NIFA                           HATCH ACT OF 1887 - NY        4411279.0
# 3     NIFA                           HATCH ACT OF 1887 - NY        4411279.0
# 4     NIFA  ANIMAL HEALTH AND DISEASE RESEARCH PROGRAM - OH          56954.0
#
#   project_start_date_x project_end_date_x agency_y  fy_total_cost_y  \
# 0            6/15/2013          2/14/2014     NIFA         490142.0
# 1            6/15/2013          2/14/2014     NIFA        4411279.0
# 2             9/1/2013          8/31/2016     NIFA         490142.0
# 3             9/1/2013          8/31/2016     NIFA        4411279.0
# 4             1/1/2013         12/31/2013     NIFA          56954.0
#
#   project_start_date_y project_end_date_y
# 0            6/15/2013          2/14/2014
# 1             9/1/2013          8/31/2016
# 2            6/15/2013          2/14/2014
# 3             9/1/2013          8/31/2016
# 4             1/1/2013         12/31/2013

# %%
merge_df.shape
# Out:
# (999, 9)

# %% [markdown]
# ### Saving a CSV
# You can save a copy of your dataframe as a .csv file.

# %%
example.to_csv("~/example_data.csv", encoding='utf8')
